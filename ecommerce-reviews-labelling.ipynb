# %% [markdown]
# # Data Loading

# %%
import pandas as pd

# %%
df =  pd.read_csv("C:\\Users\\Shubham Verma\\Project\\TextAnalytics\\amazon_dataset\\Womens Clothing E-Commerce Reviews.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %% [markdown]
# # EDA

# %%
df['Review Text'].isna().sum()
# Out:
# 845

# %%
# Dropping the missing values in the rows
df = df.dropna(subset=['Review Text','Title'], axis=0)
df = df.reset_index(drop=True)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                  0
# Clothing ID                 0
# Age                         0
# Title                       0
# Review Text                 0
# Rating                      0
# Recommended IND             0
# Positive Feedback Count     0
# Division Name              13
# Department Name            13
# Class Name                 13
# dtype: int64

# %% [markdown]
# # Data Preprocessing

# %%
# taking only one clothing id
df = df[df['Clothing ID']==1078][['Title','Review Text']]

# %%
# data cleaning
def data_preprocessing(para):
    import nltk
    from nltk.corpus import stopwords
    import string
    import re
    import spacy
    nlp = spacy.load("en_core_web_sm")
    
    para = str(para)
    stop_words = list(set(stopwords.words('english')))
    stop_words.extend(['say','alright','would','could',"okay","maybe","may","cant"])
    
    def clean(para):
        punct = set(string.punctuation)
        punct = list(set(string.punctuation))
#         punct.remove('.')
#         para = re.sub('[^a-zA-Z.]', ' ',para)
        para = para.lower().split('.')
        punc_free = [i for i in para if i not in punct]
        clean_doc = ". ".join(punc_free)
        return clean_doc
    
    clean_para = clean(para)

    allowed_postags = ['NOUN','VERB','ADV','ADJ','PROPN']
    
    def lemmatization(paragraph, allowed_postags):
        texts_lemmatized = []
        texts_stopfree = []
        doc = nlp(paragraph)
        texts_lemmatized = [token.lemma_ for token in doc if token.pos_ in allowed_postags]
        texts_stopfree = [text for text in texts_lemmatized if text not in stop_words]
        texts_stopfree = " ".join(texts_stopfree)
        return texts_stopfree
     
    data_lemmatized = lemmatization(clean_para, allowed_postags)
    return data_lemmatized

# %%
data_preprocessing("I really wanted this to work. alas, it had a strange fit for me. the straps would not stay up, and it had a weird fit under the breast. it worked standing up, but the minute i sat down it fell off my shoulders. the fabric was beautiful! and i loved that it had pockets.")
# Out:
# 'really want work strange fit strap stay weird fit breast work stand minute sit fall shoulder fabric beautiful love pocket'

# %%
# reviewlist = [sent for sent in df['Review Text']]

# %%
# reviewlist[:3]

# %%
# reviewlist = [data_preprocessing(para) for para in reviewlist]

# %%
# df['reviewlist'] = reviewlist

# %% [markdown]
# # Aspect-Opinion Mining

# %%
# !python -m spacy download en_core_web_sm

# %%
import stanza

# %%
stanza.download('en')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.3.0.json:   0%|   …
# 2022-03-10 14:03:41 INFO: Downloading default packages for language: en (English)...
# 2022-03-10 14:03:42 INFO: File exists: C:\Users\Shubham Verma\stanza_resources\en\default.zip.
# 2022-03-10 14:03:47 INFO: Finished downloading models and saved to C:\Users\Shubham Verma\stanza_resources.

# %%
nlp = stanza.Pipeline('en') # This sets up a default neural pipeline in English
# Out:
# 2022-03-10 14:03:47 INFO: Loading these models for language: en (English):
# ============================
# | Processor    | Package   |
# ----------------------------
# | tokenize     | combined  |
# | pos          | combined  |
# | lemma        | combined  |
# | depparse     | combined  |
# | sentiment    | sstplus   |
# | constituency | wsj       |
# | ner          | ontonotes |
# ============================
#
# 2022-03-10 14:03:47 INFO: Use device: cpu
# 2022-03-10 14:03:47 INFO: Loading: tokenize
# 2022-03-10 14:03:47 INFO: Loading: pos
# 2022-03-10 14:03:48 INFO: Loading: lemma
# 2022-03-10 14:03:48 INFO: Loading: depparse
# 2022-03-10 14:03:48 INFO: Loading: sentiment
# 2022-03-10 14:03:49 INFO: Loading: constituency
# 2022-03-10 14:03:49 INFO: Loading: ner
# 2022-03-10 14:03:50 INFO: Done loading processors!

# %%
#testing on cleaned paragraph : not working well as POS tags are changed after cleaning
nlp('really want work strange fit strap stay weird fit breast work stand minute sit fall shoulder fabric beautiful love pocket').sentences[0].print_dependencies()
# Out:
# ('really', 2, 'advmod')
# ('want', 0, 'root')
# ('work', 6, 'compound')
# ('strange', 6, 'amod')
# ('fit', 6, 'compound')
# ('strap', 2, 'obj')
# ('stay', 2, 'xcomp')
# ('weird', 11, 'amod')
# ('fit', 11, 'compound')
# ('breast', 11, 'compound')
# ('work', 13, 'compound')
# ('stand', 13, 'compound')
# ('minute', 14, 'compound')
# ('sit', 20, 'amod')
# ('fall', 20, 'compound')
# ('shoulder', 20, 'compound')
# ('fabric', 20, 'compound')
# ('beautiful', 20, 'amod')
# ('love', 20, 'compound')
# ('pocket', 2, 'parataxis')

# %%
#creating reviews list 
reviewText = [review for review in df['Review Text']]

# %%
# reviewText

# %%
# aspect based opinion mining by splitting each row on '.'
senti_aspects=[]
parag_aspects=[]

def aspect_opinion_mining(reviewText):
    for para in reviewText:
    #     print(para)
        for sen in para.split('.'): 
            important = nlp(sen)
            descriptive_item = ''
            target = ''
            added_terms=''
            for sent in important.sentences:
    #             print(sent)
                for wrd in sent.words:
    #                 print(wrd.text,wrd.pos,wrd.deprel)
                    if ((wrd.deprel == 'nsubj' and wrd.pos == 'NOUN') or(wrd.deprel == 'nsubj' and wrd.pos == 'PROPN')):
                        target = wrd.text
                    if wrd.pos=='ADV' and wrd.deprel =='advmod':
                        added_terms = wrd.text
                    if wrd.pos == 'ADJ':
                        descriptive_item = added_terms +' '+ wrd.text
                    if target!='' and wrd.pos=='NOUN' and wrd.deprel =='root':
                        descriptive_item = added_terms +' '+ wrd.text                    
                    if target!='' and descriptive_item!='':
                        senti_aspects.append({'aspect': target,'opinion': descriptive_item})
                        descriptive_item = ''
                        target = ''
                        added_terms=''
    #     if(senti_aspects!=[])
        parag_aspects.append(senti_aspects)
        senti_aspects=[]
    return parag_aspects

# %%
parag_aspects = aspect_opinion_mining(reviewText)

# %%
len(parag_aspects)
# Out:
# 871

# %%
parag_aspects
# Out:
# [[{'aspect': 'straps', 'opinion': ' weird'},
#   {'aspect': 'fabric', 'opinion': ' beautiful'}],
#  [{'aspect': 'one', 'opinion': ' cute'},
#   {'aspect': 'material', 'opinion': 'well difficult'}],
#  [{'aspect': 'petite', 'opinion': ' grey'}],
#  [{'aspect': 'problem', 'opinion': ' hem'}],
#  [{'aspect': 'pattern', 'opinion': 'just fun'},
#   {'aspect': 'skirt', 'opinion': ' flattering'},
#   {'aspect': 'material', 'opinion': 'too heavy'},
#   {'aspect': 'reviews', 'opinion': ' other'},
#   {'aspect': 'dress', 'opinion': ' short'}],
#  [],
#  [{'aspect': 'colors', 'opinion': ' cheerful'}],
#  [{'aspect': 'dress', 'opinion': 'really tall'}],
#  [{'aspect': 'colors', 'opinion': ' fun'},
#   {'aspect': 'top', 'opinion': ' fine'},
#   {'aspect': 'material', 'opinion': ' great'}],
#  [],
#  [{'aspect': 'dress', 'opinion': 'really cute'}],
#  [{'aspect': 'dress', 'opinion': 'very comfortable'},
#   {'aspect': 'issue', 'opinion': ' only'},
#   {'aspect': 'skirt', 'opinion': 'quite short'},
#   {'aspect': 'dress', 'opinion': ' sturdy'},
#   {'aspect': 'length', 'opinion': ' horizontal'}],
#  [{'aspect': 'hubby', 'opinion': 'more else'},
#   {'aspect': 'style', 'opinion': 'super flattering'}],
#  [],
#  [{'aspect': 'lines', 'opinion': ' horizontal'},
#   {'aspect': 'fabric', 'opinion': ' thick'}],
#  [{'aspect': 'colors', 'opinion': 'more vibrant'},
#   {'aspect': 'dress', 'opinion': 'very short'},
#   {'aspect': 'dress', 'opinion': ' generous'},
#   {'aspect': 'price', 'opinion': ' huge'}],
#  [{'aspect': 'dress', 'opinion': ' comfortable'}],
#  [{'aspect': 'length', 'opinion': ' perfect'},
#   {'aspect': 'material', 'opinion': ' appropriate'},
#   {'aspect': 'one', 'opinion': ' grey'},
#   {'aspect': 'problem', 'opinion': ' only'}],
#  [],
#  [],
#  [{'aspect': 'hem', 'opinion': 'absolutely regular'},
#   {'aspect': 'dress', 'opinion': ' large'}],
#  [{'aspect': 'embroidery', 'opinion': ' lovely'}],
#  [{'aspect': 'fabric', 'opinion': ' Comfortable'},
#   {'aspect': 'embroidery', 'opinion': ' little'},
#   {'aspect': 'p', 'opinion': 'just fine'},
#   {'aspect': 'problem', 'opinion': ' sleeves'},
#   {'aspect': 'way', 'opinion': 'too snug'},
#   {'aspect': 'things', 'opinion': 'too many'}],
#  [{'aspect': 'one', 'opinion': 'super comfortable'},
#   {'aspect': 'fits', 'opinion': ' perfect'},
#   {'aspect': 'length', 'opinion': 'most likely'}],
#  [{'aspect': 'thing', 'opinion': 'really awesome'},
#   {'aspect': 'one', 'opinion': 'potentially negative'},
#   {'aspect': 'issue', 'opinion': ' sure'}],
#  [{'aspect': 'fabric', 'opinion': 'very soft'},
#   {'aspect': 'embroidery', 'opinion': ' beautiful'}],
#  [{'aspect': 'material', 'opinion': 'so stunning'},
#   {'aspect': 'material', 'opinion': 'very soft'}],
#  [{'aspect': 'model', 'opinion': " '"}],
#  [{'aspect': 'size', 'opinion': ' small'}],
#  [{'aspect': 'cut', 'opinion': ' tight'},
#   {'aspect': 'fabric', 'opinion': ' buttery'},
#   {'aspect': 'placket', 'opinion': ' soft'},
#   {'aspect': 'pleats', 'opinion': ' different'}],
#  [{'aspect': 'frabic', 'opinion': 'recently new'},
#   {'aspect': 'slip', 'opinion': ' full'}],
#  [],
#  [{'aspect': 'cut', 'opinion': 'very flattering'},
#   {'aspect': 'material', 'opinion': ' stretchy'},
#   {'aspect': 'waist', 'opinion': ' petite'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' comfortable'}],
#  [{'aspect': 'm', 'opinion': 'too big'}],
#  [{'aspect': 'style', 'opinion': ' bohemian'},
#   {'aspect': 'style', 'opinion': ' overall'},
#   {'aspect': 'color', 'opinion': 'even black'}],
#  [{'aspect': 'dress', 'opinion': 'so fantastic'}],
#  [{'aspect': 'dress', 'opinion': 'really fun'},
#   {'aspect': 'colors', 'opinion': 'really easy'},
#   {'aspect': 'reviewer', 'opinion': ' last'},
#   {'aspect': 'dresses', 'opinion': 'very most'},
#   {'aspect': 'dress', 'opinion': 'extremely comfortable'}],
#  [{'aspect': 'dress', 'opinion': 'beautifully unique'}],
#  [{'aspect': 'sleeves', 'opinion': ' sheer'}],
#  [{'aspect': 'dress', 'opinion': ' many'},
#   {'aspect': 'hem', 'opinion': ' bottom'},
#   {'aspect': 'size', 'opinion': ' typical'}],
#  [{'aspect': 'dress', 'opinion': 'absolutely beautiful'},
#   {'aspect': 'grey', 'opinion': 'more vibrant'},
#   {'aspect': 'picture', 'opinion': ' real'},
#   {'aspect': 'red', 'opinion': ' perfect'},
#   {'aspect': 'sleeves', 'opinion': 'seriously sheer'}],
#  [{'aspect': 'fit', 'opinion': ' more'},
#   {'aspect': 'l', 'opinion': 'too big'},
#   {'aspect': 'dress', 'opinion': ' 34d'},
#   {'aspect': 'color', 'opinion': ' favorites'}],
#  [{'aspect': 'reviewers', 'opinion': ' other'}],
#  [{'aspect': 'fabric', 'opinion': ' heavy'},
#   {'aspect': 'dress', 'opinion': 'very unflattering'}],
#  [{'aspect': 'dress', 'opinion': ' grey'},
#   {'aspect': 'buttons', 'opinion': 'very tight'},
#   {'aspect': 'inventory', 'opinion': 'also online'}],
#  [{'aspect': 'shape', 'opinion': ' extra'}],
#  [{'aspect': 'fabric', 'opinion': 'so much'}],
#  [{'aspect': 'dress', 'opinion': ' cute'},
#   {'aspect': 'fit', 'opinion': 'too large'},
#   {'aspect': 'xs', 'opinion': 'too wide'},
#   {'aspect': 'grey', 'opinion': 'very blueish'},
#   {'aspect': 'pockets', 'opinion': ' awesome'}],
#  [{'aspect': 'dress', 'opinion': 'really staple'},
#   {'aspect': 'material', 'opinion': 'very nice'},
#   {'aspect': 'dress', 'opinion': 'too big'},
#   {'aspect': 'band', 'opinion': 'somewhat big'}],
#  [{'aspect': 'dress', 'opinion': 'too short'},
#   {'aspect': 'color', 'opinion': 'more earthy'}],
#  [{'aspect': 'seam', 'opinion': ' little'},
#   {'aspect': 'hem', 'opinion': ' asymmetrical'},
#   {'aspect': 'dress', 'opinion': ' under'},
#   {'aspect': 'material', 'opinion': ' over'}],
#  [{'aspect': '#39', 'opinion': ' simple'}],
#  [{'aspect': 'dress', 'opinion': 'extremely large'}],
#  [{'aspect': 'dress', 'opinion': 'too loose'},
#   {'aspect': 'material', 'opinion': 'as bright'}],
#  [{'aspect': 'dress', 'opinion': 'just amazing'},
#   {'aspect': 'drawback', 'opinion': ' only'},
#   {'aspect': 'buttons', 'opinion': ' new'}],
#  [{'aspect': 'cut', 'opinion': 'so flattering'},
#   {'aspect': 'colors', 'opinion': ' gorgeous'},
#   {'aspect': 'material', 'opinion': 'even rough'}],
#  [{'aspect': 'dress', 'opinion': 'so soft'}],
#  [{'aspect': 'colour', 'opinion': ' gorgeous'},
#   {'aspect': 'waist', 'opinion': 'much lower'},
#   {'aspect': 'pockets', 'opinion': ' nice'}],
#  [{'aspect': 'school', 'opinion': ' secular'}],
#  [{'aspect': 'dress', 'opinion': ' gorgeous'},
#   {'aspect': 'size', 'opinion': ' regular'},
#   {'aspect': 'pleats', 'opinion': ' petite'},
#   {'aspect': 'pleats', 'opinion': 'better odd'}],
#  [{'aspect': 'dress', 'opinion': ' modern'},
#   {'aspect': 'length', 'opinion': ' regular'},
#   {'aspect': 'colors', 'opinion': ' grey'},
#   {'aspect': 'colors', 'opinion': ' gorgeous'}],
#  [{'aspect': 'holes', 'opinion': ' tight'},
#   {'aspect': 'plaid', 'opinion': 'underneath nice'},
#   {'aspect': 'color', 'opinion': ' grey'}],
#  [{'aspect': 'slip', 'opinion': ' straight'}],
#  [{'aspect': 'dress', 'opinion': 'both flattering'},
#   {'aspect': 'red', 'opinion': ' deeper'}],
#  [{'aspect': 'material', 'opinion': ' high'}],
#  [],
#  [{'aspect': 'lacing', 'opinion': 'completely useless'},
#   {'aspect': 'dress', 'opinion': 'very loose'}],
#  [{'aspect': 'dress', 'opinion': ' same'}],
#  [{'aspect': 'way', 'opinion': 'too much'}],
#  [{'aspect': 'one', 'opinion': 'too full'},
#   {'aspect': 'bottom', 'opinion': 'also front'},
#   {'aspect': 'fabric', 'opinion': 'so disappointed'},
#   {'aspect': 'colors', 'opinion': ' beautiful'}],
#  [{'aspect': 'reviewers', 'opinion': ' many'},
#   {'aspect': 'sleeves', 'opinion': ' puffy'},
#   {'aspect': 'ps', 'opinion': ' perfect'}],
#  [{'aspect': 'fabric', 'opinion': ' other'},
#   {'aspect': 'sleeves', 'opinion': 'quite large'}],
#  [],
#  [],
#  [{'aspect': 'print', 'opinion': ' tall'}],
#  [{'aspect': 'tassels', 'opinion': 'so black'}],
#  [{'aspect': 'embroidery', 'opinion': ' white'},
#   {'aspect': 'dress', 'opinion': ' billowy'}],
#  [{'aspect': 'dress', 'opinion': ' second'},
#   {'aspect': 'dress', 'opinion': ' bohemian'},
#   {'aspect': 'ladies', 'opinion': ' armed'},
#   {'aspect': 'part', 'opinion': ' only'}],
#  [{'aspect': 'fabric', 'opinion': 'simply gorgeous'},
#   {'aspect': 'size', 'opinion': ' small'},
#   {'aspect': 'cut', 'opinion': 'just good'},
#   {'aspect': 'dress', 'opinion': 'entirely sure'}],
#  [{'aspect': 'pictures', 'opinion': 'then few'},
#   {'aspect': 'fit', 'opinion': ' flowy'},
#   {'aspect': 'lining', 'opinion': ' tts'},
#   {'aspect': 'colors', 'opinion': 'so many'}],
#  [{'aspect': 'complaint', 'opinion': ' only'}],
#  [{'aspect': 'sleeves', 'opinion': ' puffy'},
#   {'aspect': 'material', 'opinion': 'extremely comfortable'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' great'},
#   {'aspect': 'sleeves', 'opinion': 'well large'},
#   {'aspect': 'dress', 'opinion': ' great'},
#   {'aspect': 'material', 'opinion': ' little'},
#   {'aspect': 'top', 'opinion': ' cotton'}],
#  [],
#  [{'aspect': 'dress', 'opinion': 'so soft'},
#   {'aspect': 'stripes', 'opinion': ' fun'}],
#  [{'aspect': 'medium', 'opinion': 'generally perfect'},
#   {'aspect': 'dress', 'opinion': ' curvy'}],
#  [{'aspect': 'dress', 'opinion': ' adorable'},
#   {'aspect': "i'm", 'opinion': 'probably shortest'},
#   {'aspect': 'fabric', 'opinion': 'quite soft'}],
#  [{'aspect': 'material', 'opinion': ' soft'}],
#  [{'aspect': 'dress', 'opinion': ' great'},
#   {'aspect': 'dress', 'opinion': 'too tight'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' thicker'},
#   {'aspect': 'dress', 'opinion': 'likely many'}],
#  [{'aspect': 'material', 'opinion': 'just thin'}],
#  [{'aspect': 'price', 'opinion': ' amazing'}],
#  [{'aspect': 'dress', 'opinion': 'really cute'},
#   {'aspect': 'people', 'opinion': ' many'},
#   {'aspect': 'things', 'opinion': ' key'},
#   {'aspect': 'material', 'opinion': ' soft'},
#   {'aspect': 'arms', 'opinion': ' ok'},
#   {'aspect': 'problem', 'opinion': 'then larger'},
#   {'aspect': 'way', 'opinion': ' great'}],
#  [{'aspect': 'part', 'opinion': ' hardest'},
#   {'aspect': 'dress', 'opinion': ' slim'},
#   {'aspect': 'fabric', 'opinion': ' lower'},
#   {'aspect': 'dress', 'opinion': ' modest'}],
#  [{'aspect': 'fabric', 'opinion': ' high'},
#   {'aspect': 'fit', 'opinion': 'super comfy'}],
#  [{'aspect': 'stylist', 'opinion': ' usual'},
#   {'aspect': 'turtleneck', 'opinion': 'too tight'},
#   {'aspect': 'friend', 'opinion': 'also favorite'}],
#  [{'aspect': 'fabric', 'opinion': ' best'},
#   {'aspect': 'fabric', 'opinion': ' soft'}],
#  [{'aspect': 'cut', 'opinion': ' larger'}],
#  [{'aspect': 'dress', 'opinion': ' great'},
#   {'aspect': 'fabric', 'opinion': ' substantial'},
#   {'aspect': 'negative', 'opinion': ' only'}],
#  [{'aspect': 'fabric', 'opinion': 'very stiff'},
#   {'aspect': 'description', 'opinion': ' best'},
#   {'aspect': 'part', 'opinion': 'very nice'},
#   {'aspect': 'bottom', 'opinion': 'too ample'}],
#  [],
#  [{'aspect': 'dress', 'opinion': 'completely versatile'}],
#  [{'aspect': 'dresses', 'opinion': ' happy'},
#   {'aspect': 'size', 'opinion': 'only available'}],
#  [{'aspect': 'dress', 'opinion': 'super comfy'},
#   {'aspect': 'stripes', 'opinion': 'really horizontal'}],
#  [{'aspect': 'dress', 'opinion': 'absolutely flattering'},
#   {'aspect': 'fabric', 'opinion': ' thin'}],
#  [{'aspect': 'sizes', 'opinion': 'online difficult'},
#   {'aspect': 'dress', 'opinion': 'very cute'},
#   {'aspect': 'length', 'opinion': ' good'},
#   {'aspect': 'design', 'opinion': ' black'}],
#  [{'aspect': 'dress', 'opinion': 'super comfortable'},
#   {'aspect': 'material', 'opinion': 'very thick'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' curvier'},
#   {'aspect': 'dress', 'opinion': ' exact'}],
#  [{'aspect': 'dress', 'opinion': ' comfortable'}],
#  [],
#  [],
#  [{'aspect': 'sleeves', 'opinion': 'so small'},
#   {'aspect': 'slip', 'opinion': 'so fine'}],
#  [{'aspect': 'medium', 'opinion': ' perfect'}],
#  [{'aspect': 'quality', 'opinion': ' great'},
#   {'aspect': 'dress', 'opinion': 'too high'}],
#  [],
#  [{'aspect': 'one', 'opinion': ' turquoise'}],
#  [{'aspect': 'dress', 'opinion': ' usual'}],
#  [{'aspect': 'dress', 'opinion': 'very flattering'},
#   {'aspect': 'one', 'opinion': ' colorful'}],
#  [{'aspect': 'turtleneck', 'opinion': 'as flattering'},
#   {'aspect': 'fabric', 'opinion': ' nice'},
#   {'aspect': 'style', 'opinion': ' nice'}],
#  [],
#  [],
#  [{'aspect': 'retailer', 'opinion': 'again beautiful'},
#   {'aspect': 'material', 'opinion': ' light'}],
#  [{'aspect': 'quality', 'opinion': 'very nice'},
#   {'aspect': 'dress', 'opinion': 'really comfortable'}],
#  [{'aspect': 'shipping', 'opinion': ' quick'},
#   {'aspect': 'lines', 'opinion': ' swirly'}],
#  [{'aspect': 'dress', 'opinion': ' cheap'},
#   {'aspect': 'material', 'opinion': ' white'},
#   {'aspect': 'sweater', 'opinion': ' grey'}],
#  [{'aspect': 'dress', 'opinion': 'just bad'},
#   {'aspect': 'fabric', 'opinion': ' thin'},
#   {'aspect': 'turtleneck', 'opinion': ' tight'}],
#  [{'aspect': 'fabric', 'opinion': 'quite loose'},
#   {'aspect': 'assets', 'opinion': 'particularly clingy'},
#   {'aspect': 'swing', 'opinion': ' asymmetrical'},
#   {'aspect': 'hemline', 'opinion': 'more awkward'}],
#  [{'aspect': 'dress', 'opinion': ' neutral'},
#   {'aspect': 'issue', 'opinion': ' fabric'},
#   {'aspect': 'fabric', 'opinion': 'still weird'}],
#  [{'aspect': 'size', 'opinion': ' true'}],
#  [{'aspect': 'stretch', 'opinion': ' light'}],
#  [{'aspect': 'fit', 'opinion': ' great'},
#   {'aspect': 'quality', 'opinion': ' great'}],
#  [],
#  [{'aspect': 'navy', 'opinion': 'pretty dark'},
#   {'aspect': 'fabric', 'opinion': 'very soft'},
#   {'aspect': 'cut', 'opinion': ' more'}],
#  [{'aspect': 'thing', 'opinion': 'most important'}],
#  [],
#  [{'aspect': 'material', 'opinion': 'so soft'},
#   {'aspect': 'skirt', 'opinion': ' actual'},
#   {'aspect': 'xs', 'opinion': ' best'}],
#  [{'aspect': 'dress', 'opinion': ' perfect'},
#   {'aspect': 'fabric', 'opinion': ' soft'}],
#  [{'aspect': 'dress', 'opinion': ' fantastic'}],
#  [{'aspect': 'fabric', 'opinion': ' light'}],
#  [{'aspect': 'material', 'opinion': 'very soft'}],
#  [],
#  [{'aspect': 'dress', 'opinion': 'so excited'},
#   {'aspect': 'reviewers', 'opinion': ' other'},
#   {'aspect': 'fabric', 'opinion': ' lovely'},
#   {'aspect': 'dress', 'opinion': ' fine'}],
#  [{'aspect': 'dress', 'opinion': ' right'}],
#  [],
#  [],
#  [],
#  [{'aspect': 'xs', 'opinion': 'usually better'},
#   {'aspect': 'length', 'opinion': ' longer'},
#   {'aspect': 'problem', 'opinion': ' only'}],
#  [{'aspect': 'length', 'opinion': ' little'}],
#  [{'aspect': 'dress', 'opinion': ' beautiful'},
#   {'aspect': 'print', 'opinion': 'recently versatile'},
#   {'aspect': 'layer', 'opinion': ' top'}],
#  [],
#  [{'aspect': 'embroidery', 'opinion': 'perfectly nice'},
#   {'aspect': 'material', 'opinion': ' sure'}],
#  [{'aspect': 'sheath', 'opinion': ' inner'},
#   {'aspect': 'overlay', 'opinion': ' lattice'}],
#  [{'aspect': 'dress', 'opinion': ' unique'},
#   {'aspect': 'v-neckline', 'opinion': ' deep'},
#   {'aspect': 'detail', 'opinion': ' nice'},
#   {'aspect': 'pattern', 'opinion': ' good'},
#   {'aspect': 'dress', 'opinion': 'actually black'},
#   {'aspect': 'pockets', 'opinion': ' unlined'}],
#  [],
#  [],
#  [{'aspect': 'dress', 'opinion': ' curvy'},
#   {'aspect': 'dress', 'opinion': ' funky'}],
#  [{'aspect': 'fabrics', 'opinion': ' beautiful'},
#   {'aspect': 'fit', 'opinion': 'so strange'}],
#  [{'aspect': 'sleeves', 'opinion': 'really big'}],
#  [{'aspect': 'dress', 'opinion': ' gorgeous'},
#   {'aspect': 'zipper', 'opinion': ' tricky'},
#   {'aspect': 'dress', 'opinion': 'too tight'},
#   {'aspect': 'zipper', 'opinion': ' tricky'},
#   {'aspect': 'picture', 'opinion': 'mostly blac'}],
#  [],
#  [],
#  [{'aspect': 'fit', 'opinion': 'just bad'},
#   {'aspect': 'top', 'opinion': ' fine'},
#   {'aspect': 'half', 'opinion': ' bottom'},
#   {'aspect': 'gaps', 'opinion': 'too unattractive'}],
#  [{'aspect': 'photos', 'opinion': ' gorgeous'},
#   {'aspect': 'material', 'opinion': ' iridescent'}],
#  [{'aspect': 'details', 'opinion': 'too much'},
#   {'aspect': 'length', 'opinion': 'very versatile'}],
#  [{'aspect': 'dress', 'opinion': ' beautiful'}],
#  [{'aspect': 'design', 'opinion': 'super flattering'}],
#  [{'aspect': 'embroidery', 'opinion': ' stunning'},
#   {'aspect': 'color', 'opinion': ' difficult'}],
#  [{'aspect': 'dress', 'opinion': ' perfect'},
#   {'aspect': 'part', 'opinion': ' sheer'}],
#  [{'aspect': 'dress', 'opinion': ' adorable'},
#   {'aspect': 'size', 'opinion': 'only available'},
#   {'aspect': 'holes', 'opinion': 'then top'}],
#  [{'aspect': 'dress', 'opinion': ' great'},
#   {'aspect': 'dress', 'opinion': ' great'}],
#  [{'aspect': 'thing', 'opinion': 'then tent-like'}],
#  [{'aspect': 'band', 'opinion': ' big'}],
#  [{'aspect': 'size', 'opinion': ' best'},
#   {'aspect': 'red', 'opinion': 'both gorgeous'},
#   {'aspect': 'wasit', 'opinion': ' comfortable'}],
#  [{'aspect': 'length', 'opinion': ' good'},
#   {'aspect': 'waistband', 'opinion': 'right elastic'}],
#  [{'aspect': 'reviewers', 'opinion': ' other'},
#   {'aspect': 'fabric', 'opinion': 'too much'}],
#  [{'aspect': 'fit', 'opinion': ' good'}],
#  [],
#  [],
#  [{'aspect': 'model', 'opinion': ' tall'},
#   {'aspect': 'dress', 'opinion': 'absolutely fabulous'},
#   {'aspect': 'dress', 'opinion': 'right small'},
#   {'aspect': 'lining', 'opinion': ' outer'}],
#  [{'aspect': 'shirt', 'opinion': 'too poofy'}],
#  [{'aspect': 'expectations', 'opinion': ' neutral'},
#   {'aspect': 'dresses', 'opinion': 'sometimes elastic'},
#   {'aspect': 'fit', 'opinion': 'more brown'}],
#  [{'aspect': 'v-neck', 'opinion': ' perfect'},
#   {'aspect': 'sleeves', 'opinion': ' perfect'},
#   {'aspect': 'lining', 'opinion': 'super soft'},
#   {'aspect': 'problem', 'opinion': ' only'}],
#  [{'aspect': 'dress', 'opinion': ' rare'},
#   {'aspect': 'one', 'opinion': 'nearly impossible'}],
#  [],
#  [{'aspect': 'linen', 'opinion': ' big'},
#   {'aspect': 'length', 'opinion': ' few'},
#   {'aspect': 'slip', 'opinion': 'also separate'}],
#  [{'aspect': 'length', 'opinion': ' Perfect'}],
#  [{'aspect': 'detail', 'opinion': 'Really cute'},
#   {'aspect': 'dress', 'opinion': ' distinctive'},
#   {'aspect': 'slip', 'opinion': ' soft'},
#   {'aspect': "i'm", 'opinion': 'often relaxed'},
#   {'aspect': 'one', 'opinion': 'too billowy'}],
#  [],
#  [],
#  [{'aspect': 'dress', 'opinion': ' blue'}],
#  [{'aspect': 'detail', 'opinion': 'really cute'}],
#  [{'aspect': 'dress', 'opinion': ' amazing'}],
#  [{'aspect': 'guy', 'opinion': 'already great'},
#   {'aspect': 'dress', 'opinion': 'just defective'},
#   {'aspect': 'dress', 'opinion': ' burnt'}],
#  [{'aspect': 'length', 'opinion': ' great'}],
#  [{'aspect': 'mango', 'opinion': ' disappointed'},
#   {'aspect': 'color', 'opinion': ' dark'}],
#  [],
#  [{'aspect': 'shade', 'opinion': 'quite muddy'},
#   {'aspect': 'photos', 'opinion': 'not vibrant'}],
#  [{'aspect': 'fit', 'opinion': 'beautifully fantastic'}],
#  [],
#  [{'aspect': 'fit', 'opinion': ' great'},
#   {'aspect': 'complaint', 'opinion': ' only'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' western'}],
#  [{'aspect': 'fabric', 'opinion': 'absolutely gorgeous'}],
#  [{'aspect': 'problem', 'opinion': ' biggest'},
#   {'aspect': 'style', 'opinion': 'so straight'},
#   {'aspect': 'dress', 'opinion': ' large'},
#   {'aspect': 'area', 'opinion': 'however tight'}],
#  [{'aspect': 'dress', 'opinion': 'super cute'},
#   {'aspect': 'material', 'opinion': ' less'},
#   {'aspect': 'arms', 'opinion': ' smaller'},
#   {'aspect': 'area', 'opinion': ' hips'}],
#  [{'aspect': 'print', 'opinion': 'so thrilled'},
#   {'aspect': 'lot', 'opinion': 'very wide'},
#   {'aspect': 'images', 'opinion': 'so fine'}],
#  [{'aspect': 'heads', 'opinion': ' dark'}],
#  [{'aspect': 'skirt', 'opinion': 'though extra'}],
#  [],
#  [{'aspect': 'fabric', 'opinion': 'too much'},
#   {'aspect': 'lining', 'opinion': ' heavier'}],
#  [{'aspect': 'reviewers', 'opinion': ' other'}],
#  [{'aspect': 'one', 'opinion': 'pretty big'}],
#  [{'aspect': 'others', 'opinion': ' large'},
#   {'aspect': 'design', 'opinion': 'also perfect'}],
#  [{'aspect': 'reviewers', 'opinion': ' other'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' loose'}],
#  [{'aspect': 'escalante', 'opinion': ' marvelous'},
#   {'aspect': 'reviewer', 'opinion': ' same'}],
#  [{'aspect': 'sleeves', 'opinion': 'nicely annoying'},
#   {'aspect': 'length', 'opinion': ' right'}],
#  [{'aspect': 'dress', 'opinion': 'also tall'}],
#  [{'aspect': 'fitting', 'opinion': ' loose'}],
#  [],
#  [{'aspect': 'Dress', 'opinion': 'very cute'},
#   {'aspect': 'color', 'opinion': 'pretty deep'},
#   {'aspect': 'lot', 'opinion': 'very slight'},
#   {'aspect': 'tailor', 'opinion': ' good'}],
#  [{'aspect': 'colors', 'opinion': ' beautiful'},
#   {'aspect': 'material', 'opinion': ' substantial'}],
#  [{'aspect': 'room', 'opinion': 'however unforgiving'}],
#  [],
#  [{'aspect': 'chest', 'opinion': ' aghast'},
#   {'aspect': 'body', 'opinion': ' tight'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' gorgeous'}],
#  [{'aspect': 'dress', 'opinion': ' fabulous'},
#   {'aspect': 'fit', 'opinion': ' overall'},
#   {'aspect': 'length', 'opinion': 'also great'},
#   {'aspect': 'dresses', 'opinion': ' many'},
#   {'aspect': 'holes', 'opinion': 'also great'},
#   {'aspect': 'lack', 'opinion': ' only'}],
#  [{'aspect': 'length', 'opinion': 'so fine'}],
#  [{'aspect': 'fit', 'opinion': ' perfect'},
#   {'aspect': 'reviews', 'opinion': ' sure'}],
#  [{'aspect': 'patters', 'opinion': 'more stunning'},
#   {'aspect': 'pockets', 'opinion': 'as many'},
#   {'aspect': 'fit', 'opinion': ' tricky'}],
#  [{'aspect': 'armholes', 'opinion': ' big'}],
#  [{'aspect': 'one', 'opinion': 'often same'},
#   {'aspect': 'material', 'opinion': ' thick'},
#   {'aspect': 'sleeves', 'opinion': ' nice'}],
#  [{'aspect': 'dress', 'opinion': ' simple'}],
#  [],
#  [{'aspect': 'color', 'opinion': 'very peppery'}],
#  [{'aspect': 'associate', 'opinion': 'super cute'}],
#  [],
#  [],
#  [{'aspect': 'mixture', 'opinion': 'very unique'},
#   {'aspect': 'xs', 'opinion': ' regular'},
#   {'aspect': 'color', 'opinion': ' true'},
#   {'aspect': 'sleeves', 'opinion': ' little'}],
#  [{'aspect': 'smalls', 'opinion': 'usually extra'},
#   {'aspect': 'sa', 'opinion': 'even smaller'},
#   {'aspect': 'sizes', 'opinion': ' bottom'}],
#  [],
#  [{'aspect': 'picture', 'opinion': ' unique'}],
#  [{'aspect': 'fabric', 'opinion': ' thin'},
#   {'aspect': 'color', 'opinion': 'pretty person'},
#   {'aspect': 'photo', 'opinion': ' nice'},
#   {'aspect': 'dress', 'opinion': 'actually boring'}],
#  [{'aspect': 'needles', 'opinion': 'pretty little'},
#   {'aspect': 'wool', 'opinion': 'pretty high'}],
#  [{'aspect': 'dress', 'opinion': 'only tall'}],
#  [{'aspect': 'style', 'opinion': 'so nice'},
#   {'aspect': 'fabric', 'opinion': 'very stiff'}],
#  [{'aspect': 'shape', 'opinion': ' nice'}],
#  [{'aspect': 'photos', 'opinion': 'as gauzy'}],
#  [{'aspect': 'dresses', 'opinion': 'sometimes a-line'}],
#  [{'aspect': 'dress', 'opinion': 'so good'},
#   {'aspect': 'material', 'opinion': ' poofy'}],
#  [{'aspect': 'sizes', 'opinion': ' same'},
#   {'aspect': 'material', 'opinion': ' beautiful'}],
#  [{'aspect': 'armholes', 'opinion': 'too tight'}],
#  [],
#  [],
#  [{'aspect': 'dress', 'opinion': ' pregnant'},
#   {'aspect': 'quality', 'opinion': 'otherwise lovely'},
#   {'aspect': 'mixing', 'opinion': ' great'}],
#  [{'aspect': 'dress', 'opinion': 'still shapeless'},
#   {'aspect': 'store', 'opinion': 'so many'},
#   {'aspect': 'details', 'opinion': ' high'},
#   {'aspect': 'fit', 'opinion': 'just better'}],
#  [],
#  [{'aspect': 'photos', 'opinion': 'even hot'},
#   {'aspect': 'weight', 'opinion': ' synthetic'},
#   {'aspect': 'fabric', 'opinion': ' maroon'},
#   {'aspect': "i'm", 'opinion': ' long'}],
#  [{'aspect': 'dress', 'opinion': 'well flattering'}],
#  [{'aspect': 'pictures', 'opinion': 'accurately large'},
#   {'aspect': 'dress', 'opinion': 'most unflattering'}],
#  [{'aspect': 'dress', 'opinion': ' fantastic'},
#   {'aspect': 'gals', 'opinion': ' other'}],
#  [{'aspect': 'dress', 'opinion': ' online'},
#   {'aspect': 'lining', 'opinion': 'really soft'},
#   {'aspect': 'sleeves', 'opinion': 'really cute'}],
#  [],
#  [{'aspect': 'pink', 'opinion': ' perfect'}],
#  [{'aspect': 'pink', 'opinion': 'just beautiful'}],
#  [{'aspect': 'photos', 'opinion': ' beautiful'},
#   {'aspect': 'pink', 'opinion': ' gorgeous'}],
#  [{'aspect': 'dress', 'opinion': ' wrinkled'},
#   {'aspect': 'dress', 'opinion': ' entire'}],
#  [],
#  [],
#  [{'aspect': 'dress', 'opinion': ' awesome'},
#   {'aspect': 'pink', 'opinion': ' ridiculous'},
#   {'aspect': 'pink', 'opinion': ' only'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' elegant'},
#   {'aspect': 'dress', 'opinion': 'more rigid'}],
#  [{'aspect': 'dress', 'opinion': ' great'},
#   {'aspect': 'style', 'opinion': 'very flattering'}],
#  [{'aspect': 'dress', 'opinion': ' huge'},
#   {'aspect': 'dress', 'opinion': 'still big'}],
#  [{'aspect': 'pink', 'opinion': 'really bright'}],
#  [],
#  [{'aspect': 'dress', 'opinion': 'down other'},
#   {'aspect': 'feel', 'opinion': ' amazing'}],
#  [{'aspect': 'dress', 'opinion': 'so much'},
#   {'aspect': 'movement', 'opinion': 'very fun'},
#   {'aspect': 'piping', 'opinion': ' green'}],
#  [{'aspect': 'xs', 'opinion': ' perfect'},
#   {'aspect': 'color', 'opinion': ' gorgeous'},
#   {'aspect': 'fabric', 'opinion': ' crepe'},
#   {'aspect': 'iron', 'opinion': ' dry'}],
#  [{'aspect': 'gauze', 'opinion': 'sometimes cheap'},
#   {'aspect': 'trim', 'opinion': 'more tone'},
#   {'aspect': 'photo', 'opinion': ' negative'}],
#  [{'aspect': 'colors', 'opinion': ' amazing'},
#   {'aspect': 'dress', 'opinion': ' curvy'},
#   {'aspect': 'part', 'opinion': ' best'}],
#  [],
#  [],
#  [{'aspect': 'fabric', 'opinion': ' high'},
#   {'aspect': 'size', 'opinion': ' usual'},
#   {'aspect': 'fit', 'opinion': ' comfortable'}],
#  [{'aspect': 'slip', 'opinion': 'underneath big'},
#   {'aspect': 'dress', 'opinion': ' fine'}],
#  [{'aspect': 'dress', 'opinion': 'really lovely'},
#   {'aspect': 'fit', 'opinion': ' perfect'},
#   {'aspect': 'length', 'opinion': 'too short'},
#   {'aspect': 'dress', 'opinion': 'very busty'},
#   {'aspect': 'fit', 'opinion': 'usually only'},
#   {'aspect': 'thing', 'opinion': ' crazy'}],
#  [{'aspect': 'fit', 'opinion': 'extremely loose'},
#   {'aspect': 'photo', 'opinion': ' blue'},
#   {'aspect': 'dress', 'opinion': ' accurate'},
#   {'aspect': 'photo', 'opinion': ' other'},
#   {'aspect': 'dress', 'opinion': 'then bigger'}],
#  [],
#  [],
#  [{'aspect': 'dress', 'opinion': 'usually leery'}],
#  [{'aspect': 'dress', 'opinion': 'absolutely adorable'},
#   {'aspect': 'design', 'opinion': 'so worth'}],
#  [{'aspect': 'dress', 'opinion': 'too short'},
#   {'aspect': 'slip', 'opinion': 'slightly tight'}],
#  [{'aspect': 'length', 'opinion': 'very nice'},
#   {'aspect': 'wish', 'opinion': ' only'},
#   {'aspect': 'colors', 'opinion': ' better'}],
#  [{'aspect': 'dress', 'opinion': 'really nice'},
#   {'aspect': 'slip', 'opinion': ' snug'},
#   {'aspect': 'part', 'opinion': ' outer'}],
#  [{'aspect': 'comments', 'opinion': ' stiff'}],
#  [{'aspect': 'pink', 'opinion': ' Pale'},
#   {'aspect': 'dress', 'opinion': 'very happy'}],
#  [],
#  [],
#  [{'aspect': 'feel', 'opinion': ' young'},
#   {'aspect': 'dress', 'opinion': ' exception'}],
#  [{'aspect': 'dress', 'opinion': ' adorable'},
#   {'aspect': 'store', 'opinion': ' local'},
#   {'aspect': 'difference', 'opinion': ' biggest'},
#   {'aspect': 'dress', 'opinion': ' flowy'}],
#  [{'aspect': 'one', 'opinion': 'only smaller'}],
#  [{'aspect': 'colors', 'opinion': 'quite happy'},
#   {'aspect': 'skirt', 'opinion': ' happy'},
#   {'aspect': 'size', 'opinion': ' full'},
#   {'aspect': 'stretch', 'opinion': 'so someth'}],
#  [{'aspect': 'thing', 'opinion': ' interesting'},
#   {'aspect': 'dress', 'opinion': ' pink'}],
#  [],
#  [],
#  [],
#  [{'aspect': 'arms', 'opinion': 'perfectly personal'}],
#  [{'aspect': 'dress', 'opinion': ' little'},
#   {'aspect': 'colors', 'opinion': 'so beautiful'},
#   {'aspect': 'fabric', 'opinion': 'so light'}],
#  [{'aspect': 'dress', 'opinion': ' absolute'},
#   {'aspect': 'quality', 'opinion': ' great'},
#   {'aspect': 'fit', 'opinion': ' comfortable'},
#   {'aspect': 'slip', 'opinion': 'perfectly outer'},
#   {'aspect': 'layer', 'opinion': ' delicate'}],
#  [{'aspect': 'portion', 'opinion': 'quite flowy'},
#   {'aspect': 'slip', 'opinion': ' large'}],
#  [],
#  [{'aspect': 'dress', 'opinion': 'really sweet'},
#   {'aspect': 'colors', 'opinion': ' soft'},
#   {'aspect': 'dress', 'opinion': ' perfect'},
#   {'aspect': 'seam', 'opinion': ' lower'}],
#  [{'aspect': 'dress', 'opinion': ' cute'},
#   {'aspect': 'sleeves', 'opinion': ' tight'},
#   {'aspect': 'skirt', 'opinion': 'already lot'},
#   {'aspect': 'part', 'opinion': ' good'}],
#  [{'aspect': 'slip', 'opinion': 'underneath tight'},
#   {'aspect': 'slip', 'opinion': 'still fine'},
#   {'aspect': 'concern', 'opinion': ' other'},
#   {'aspect': 'dress', 'opinion': ' worried'}],
#  [{'aspect': 'length', 'opinion': ' perfect'}],
#  [{'aspect': 'spring', 'opinion': 'immediately opposite'},
#   {'aspect': 'dress', 'opinion': ' obvious'}],
#  [{'aspect': 'dress', 'opinion': 'extremely feminine'},
#   {'aspect': 'liner', 'opinion': ' unsung'},
#   {'aspect': 'dress', 'opinion': 'cleverly windy'},
#   {'aspect': 'fabric', 'opinion': ' opaque'},
#   {'aspect': 'fabric', 'opinion': ' sheer'},
#   {'aspect': 'details', 'opinion': ' breathtaking'}],
#  [{'aspect': 'shape', 'opinion': ' true'}],
#  [{'aspect': 'dress', 'opinion': ' cute'},
#   {'aspect': 'dress', 'opinion': 'longer back'},
#   {'aspect': 'fabric', 'opinion': ' necessary'}],
#  [{'aspect': 'dress', 'opinion': ' beautiful'},
#   {'aspect': 'half', 'opinion': ' bottom'}],
#  [],
#  [],
#  [{'aspect': 'fabric', 'opinion': ' soft'},
#   {'aspect': 'length', 'opinion': ' flowey'}],
#  [{'aspect': 'design', 'opinion': ' adorable'},
#   {'aspect': 'rompers', 'opinion': 'soo cute'}],
#  [{'aspect': 'flowy', 'opinion': ' great'},
#   {'aspect': 'length', 'opinion': 'longer most'},
#   {'aspect': 'waist', 'opinion': 'definitely elastic'}],
#  [{'aspect': 'pattern', 'opinion': ' complicated'}],
#  [{'aspect': 'romper', 'opinion': ' cute'},
#   {'aspect': 'problem', 'opinion': 'however real'},
#   {'aspect': 'reviewer', 'opinion': ' same'}],
#  [{'aspect': 'garment', 'opinion': ' loose'},
#   {'aspect': 'shoulders', 'opinion': ' roomy'}],
#  [{'aspect': 'one', 'opinion': 'really cute'}],
#  [{'aspect': 'complaint', 'opinion': ' tiny'},
#   {'aspect': 'snap', 'opinion': ' top'},
#   {'aspect': 'rest', 'opinion': 'all good'}],
#  [{'aspect': 'part', 'opinion': ' bottom'},
#   {'aspect': 'print', 'opinion': 'super cute'}],
#  [{'aspect': 'waist', 'opinion': 'quite small'}],
#  [{'aspect': 'reviews', 'opinion': ' other'}],
#  [{'aspect': 'romper', 'opinion': ' fabulous'},
#   {'aspect': 'color', 'opinion': ' great'},
#   {'aspect': 'struggle', 'opinion': ' hard'},
#   {'aspect': 'fabric', 'opinion': ' lightweight'}],
#  [],
#  [],
#  [{'aspect': 'print', 'opinion': ' fun'},
#   {'aspect': 'grommets', 'opinion': ' little'},
#   {'aspect': 'looseness', 'opinion': ' good'},
#   {'aspect': 'waistline', 'opinion': ' high-waisted'}],
#  [{'aspect': 'fit', 'opinion': ' other'},
#   {'aspect': 'slip', 'opinion': ' nice'},
#   {'aspect': 'sleeves', 'opinion': 'too keen'},
#   {'aspect': 'size', 'opinion': 'only smallest'}],
#  [{'aspect': 'lining', 'opinion': 'wide true'},
#   {'aspect': 'overlay', 'opinion': ' loose'},
#   {'aspect': 'design', 'opinion': 'pretty nice'},
#   {'aspect': 'studs', 'opinion': ' edgier'},
#   {'aspect': 'cut', 'opinion': ' flattering'}],
#  [{'aspect': 'dress', 'opinion': ' first'},
#   {'aspect': 'trim', 'opinion': ' black'}],
#  [{'aspect': 'dress', 'opinion': ' little'}],
#  [],
#  [],
#  [],
#  [],
#  [{'aspect': 'reviewer', 'opinion': ' different'},
#   {'aspect': 'colors', 'opinion': 'online accurate'}],
#  [{'aspect': 'hem', 'opinion': ' petite'}],
#  [],
#  [{'aspect': 'waist', 'opinion': ' gorgeous'},
#   {'aspect': 'length', 'opinion': ' accurate'}],
#  [{'aspect': 'dress', 'opinion': 'so comfortable'}],
#  [{'aspect': 'design', 'opinion': ' adorable'},
#   {'aspect': 'fit', 'opinion': 'really flattering'},
#   {'aspect': 'design', 'opinion': ' big'}],
#  [{'aspect': 'shape', 'opinion': 'otherwise tented'},
#   {'aspect': 'off', 'opinion': ' comfortable'}],
#  [{'aspect': 'fabrics', 'opinion': ' elegant'}],
#  [{'aspect': 'dress', 'opinion': 'absolutely hideous'}],
#  [{'aspect': 'embroidery', 'opinion': ' bright'},
#   {'aspect': 'layers', 'opinion': ' great'},
#   {'aspect': 'patterns', 'opinion': ' busy'},
#   {'aspect': 'dilemma', 'opinion': ' fold'},
#   {'aspect': 'material', 'opinion': ' polyester'}],
#  [{'aspect': 'dress', 'opinion': ' bottom'},
#   {'aspect': 'top', 'opinion': ' full'},
#   {'aspect': 'dress', 'opinion': ' peasant'},
#   {'aspect': 'women', 'opinion': ' rural'}],
#  [{'aspect': 'layer', 'opinion': ' outer'},
#   {'aspect': 'stitching', 'opinion': 'also orange'}],
#  [{'aspect': 'pieces', 'opinion': ' transparent'},
#   {'aspect': 'lining', 'opinion': ' opaque'},
#   {'aspect': 'size', 'opinion': 'too big'},
#   {'aspect': 'look', 'opinion': 'so bad'}],
#  [],
#  [{'aspect': 'colors', 'opinion': ' beautiful'},
#   {'aspect': 'fabric', 'opinion': ' blue'},
#   {'aspect': 'empire', 'opinion': 'so particular'}],
#  [{'aspect': 'length', 'opinion': ' perfect'},
#   {'aspect': 'dress', 'opinion': ' big'},
#   {'aspect': 'dress', 'opinion': 'so regular'},
#   {'aspect': 't', 'opinion': 'perfectly 5&'},
#   {'aspect': 'dress', 'opinion': ' big'},
#   {'aspect': 'length', 'opinion': 'also perfect'}],
#  [],
#  [{'aspect': 'over-dress', 'opinion': ' beautiful'},
#   {'aspect': 'under-slip', 'opinion': 'very tight'}],
#  [{'aspect': 'sleeves', 'opinion': 'slightly full'},
#   {'aspect': 'slip', 'opinion': ' tts'},
#   {'aspect': 'dress', 'opinion': ' outer'},
#   {'aspect': 'dress', 'opinion': 'just baggy'}],
#  [],
#  [{'aspect': 'length', 'opinion': ' shorter'},
#   {'aspect': 'colors', 'opinion': ' fun'},
#   {'aspect': 'sparkle', 'opinion': ' appropriate'},
#   {'aspect': 'thing', 'opinion': ' only'},
#   {'aspect': 'embroidery', 'opinion': 'really high'},
#   {'aspect': 'top', 'opinion': ' little'},
#   {'aspect': 'feel', 'opinion': ' thick'}],
#  [{'aspect': 'dresses', 'opinion': 'just retro'}],
#  [{'aspect': 'sleeves', 'opinion': ' voluminous'}],
#  [],
#  [],
#  [{'aspect': 'fit', 'opinion': ' beautiful'},
#   {'aspect': 'pictures', 'opinion': ' nice'}],
#  [{'aspect': 'size', 'opinion': ' perfect'}],
#  [{'aspect': 'fabric', 'opinion': ' same'},
#   {'aspect': 'problem', 'opinion': ' particular'},
#   {'aspect': 'pattern', 'opinion': ' little'},
#   {'aspect': 'pattern', 'opinion': ' different'}],
#  [{'aspect': 'holes', 'opinion': 'very interesting'},
#   {'aspect': 'dress', 'opinion': ' fat'},
#   {'aspect': 'material', 'opinion': ' soft'}],
#  [{'aspect': 'material', 'opinion': 'well nice'},
#   {'aspect': 'slits', 'opinion': ' bigger'},
#   {'aspect': 'neckline', 'opinion': ' wide'}],
#  [],
#  [{'aspect': 'woman', 'opinion': ' colder'}],
#  [{'aspect': 'thing', 'opinion': ' only'},
#   {'aspect': 'arm', 'opinion': 'somewhat tight'},
#   {'aspect': 'dress', 'opinion': ' wise'}],
#  [],
#  [],
#  [{'aspect': 'back', 'opinion': 'somewhat short'},
#   {'aspect': 'lining', 'opinion': ' awkward'},
#   {'aspect': 'material', 'opinion': 'very thin'},
#   {'aspect': 'dress', 'opinion': 'overall nice'}],
#  [{'aspect': "i'm", 'opinion': ' petite'},
#   {'aspect': 'fiber', 'opinion': ' natural'},
#   {'aspect': 'sleeves', 'opinion': ' large'},
#   {'aspect': 'bodice', 'opinion': 'more true'}],
#  [{'aspect': 'colors', 'opinion': ' brighter'}],
#  [{'aspect': 'reviews', 'opinion': ' Other'}],
#  [{'aspect': 'front', 'opinion': 'much shorter'},
#   {'aspect': 'front', 'opinion': 'too short'},
#   {'aspect': 'dress', 'opinion': 'underneath blue'},
#   {'aspect': 'center', 'opinion': ' sheer'},
#   {'aspect': 'dress', 'opinion': ' special'}],
#  [{'aspect': 'dress', 'opinion': 'so cute'},
#   {'aspect': 'button', 'opinion': 'very low'},
#   {'aspect': 'sleeve', 'opinion': 'not mid'}],
#  [{'aspect': 'dress', 'opinion': 'really sure'},
#   {'aspect': 'reviewer', 'opinion': 'very excited'},
#   {'aspect': 'slip', 'opinion': 'underneath great'}],
#  [{'aspect': 'fabric', 'opinion': 'too hot'},
#   {'aspect': 'strip', 'opinion': 'fyi first'}],
#  [{'aspect': 'lace', 'opinion': ' soft'}],
#  [],
#  [{'aspect': 'dress', 'opinion': 'too short'},
#   {'aspect': 'dress', 'opinion': 'terribly noticeable'}],
#  [{'aspect': 'dress', 'opinion': ' broad'},
#   {'aspect': 'snag', 'opinion': ' other'},
#   {'aspect': 'fabric', 'opinion': ' rustic'},
#   {'aspect': 'snag', 'opinion': ' terrible'},
#   {'aspect': 'friend', 'opinion': ' same'}],
#  [{'aspect': 'pattern', 'opinion': ' careful'}],
#  [{'aspect': 'reviewers', 'opinion': ' other'},
#   {'aspect': 'dress', 'opinion': 'easily classic'},
#   {'aspect': 'potential', 'opinion': 'too high'},
#   {'aspect': 'slip', 'opinion': 'also tiny'}],
#  [],
#  [{'aspect': 'dress', 'opinion': 'so cute'},
#   {'aspect': 'fabric', 'opinion': 'so much'},
#   {'aspect': 'quality', 'opinion': ' better'}],
#  [],
#  [{'aspect': 'pulling', 'opinion': ' bigger'},
#   {'aspect': 'colors', 'opinion': ' perfect'}],
#  [{'aspect': 'material', 'opinion': ' substantial'},
#   {'aspect': 'one', 'opinion': 'sometimes regular'},
#   {'aspect': 'sleeves', 'opinion': ' long'}],
#  [{'aspect': 'fabric', 'opinion': ' thick'},
#   {'aspect': 'cut', 'opinion': ' loose'},
#   {'aspect': 'patterns', 'opinion': ' different'},
#   {'aspect': 'colors', 'opinion': ' gorgeous'},
#   {'aspect': 'buttons', 'opinion': ' sturdy'},
#   {'aspect': '00p', 'opinion': 'just snugger'},
#   {'aspect': 'length', 'opinion': 'slightly knee'}],
#  [{'aspect': 'dress', 'opinion': 'so ready'},
#   {'aspect': 'dress', 'opinion': ' big'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' other'},
#   {'aspect': 'maeve', 'opinion': ' large'}],
#  [],
#  [{'aspect': 'dresses', 'opinion': ' more'}],
#  [{'aspect': 'cut', 'opinion': ' flattering'},
#   {'aspect': 'colors', 'opinion': ' rich'},
#   {'aspect': 'part', 'opinion': ' see-though'}],
#  [{'aspect': 'dress', 'opinion': 'very cute'},
#   {'aspect': 'material', 'opinion': ' little'},
#   {'aspect': 'part', 'opinion': ' top'}],
#  [{'aspect': 'dress', 'opinion': 'super flattering'}],
#  [{'aspect': 'print', 'opinion': 'much better'},
#   {'aspect': 'top', 'opinion': ' flattering'},
#   {'aspect': 'rest', 'opinion': ' fine'}],
#  [{'aspect': 'neckline', 'opinion': ' sheer'},
#   {'aspect': 'converse', 'opinion': 'also white'}],
#  [{'aspect': 'dress', 'opinion': ' perfect'},
#   {'aspect': 'complaint', 'opinion': ' only'},
#   {'aspect': 'design', 'opinion': 'overall beautiful'}],
#  [],
#  [],
#  [{'aspect': 'order', 'opinion': ' online'}],
#  [{'aspect': 'slip', 'opinion': ' least'}],
#  [{'aspect': 'blue', 'opinion': ' great'},
#   {'aspect': 'length', 'opinion': 'well knee'}],
#  [{'aspect': 'fit', 'opinion': ' wonderful'},
#   {'aspect': 'color', 'opinion': 'almost neon'}],
#  [{'aspect': 'dress', 'opinion': ' small'},
#   {'aspect': 'dress', 'opinion': ' bigger'}],
#  [{'aspect': 'dress', 'opinion': 'too much'}],
#  [{'aspect': 'dress', 'opinion': ' great'}],
#  [{'aspect': 'fit', 'opinion': 'Very pretty'}],
#  [{'aspect': 'embroidery', 'opinion': ' great'},
#   {'aspect': 'slip', 'opinion': 'anyway pretty'}],
#  [{'aspect': 'seasons', 'opinion': ' Nice'}],
#  [{'aspect': 'stature', 'opinion': 'online pettie'}],
#  [{'aspect': 'fabric', 'opinion': 'so cute'},
#   {'aspect': 'fit', 'opinion': ' great'}],
#  [{'aspect': 'rest', 'opinion': ' tight'}],
#  [{'aspect': 'colors', 'opinion': ' great'}],
#  [{'aspect': 'slip', 'opinion': ' fine'},
#   {'aspect': 'shell', 'opinion': ' outer'},
#   {'aspect': 'check', 'opinion': 'so second'},
#   {'aspect': 'fabric', 'opinion': 'pretty cute'}],
#  [],
#  [{'aspect': 'Dress', 'opinion': ' true'}],
#  [],
#  [],
#  [],
#  [{'aspect': 'colors', 'opinion': 'pretty pink'},
#   {'aspect': 'detail', 'opinion': ' nice'},
#   {'aspect': 'slip', 'opinion': 'underneath form'},
#   {'aspect': 'dress', 'opinion': 'very large'},
#   {'aspect': 'material', 'opinion': ' cheap'}],
#  [{'aspect': 'fit', 'opinion': ' perfect'}],
#  [{'aspect': 'slip', 'opinion': 'very small'},
#   {'aspect': 'dress', 'opinion': ' other'},
#   {'aspect': 'pattern', 'opinion': ' appropriate'},
#   {'aspect': 'sleeves', 'opinion': 'usually right'}],
#  [{'aspect': 'sizing', 'opinion': ' loose'}],
#  [{'aspect': 'dress', 'opinion': ' adorable'}],
#  [{'aspect': 'retailer', 'opinion': ' classic'}],
#  [{'aspect': 'material', 'opinion': ' adorable'},
#   {'aspect': 'design', 'opinion': ' short'}],
#  [{'aspect': 'color', 'opinion': 'unfortunatly aweful'},
#   {'aspect': 'striping', 'opinion': 'more red'},
#   {'aspect': "dind't", 'opinion': ' flattering'},
#   {'aspect': 'dress', 'opinion': 'so good'}],
#  [{'aspect': 'dress', 'opinion': ' gorgeous'},
#   {'aspect': 'size', 'opinion': 'usually great'},
#   {'aspect': 'plenty', 'opinion': ' chested'},
#   {'aspect': 'dress', 'opinion': ' lightweight'}],
#  [{'aspect': 'dress', 'opinion': 'really gorgeous'},
#   {'aspect': 'room', 'opinion': 'much extra'},
#   {'aspect': 'dress', 'opinion': ' excellent'}],
#  [{'aspect': 'zipper', 'opinion': ' stuck'},
#   {'aspect': 'tie', 'opinion': 'very cute'}],
#  [{'aspect': 'part', 'opinion': ' top'},
#   {'aspect': 'sleeves', 'opinion': ' nice'},
#   {'aspect': 'tie', 'opinion': ' little'}],
#  [{'aspect': 'woman', 'opinion': ' same'}],
#  [],
#  [{'aspect': 'print', 'opinion': ' pretty'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' cute'},
#   {'aspect': 'print', 'opinion': ' cute'},
#   {'aspect': 'tie', 'opinion': ' fun'}],
#  [{'aspect': 'dress', 'opinion': ' opitome'},
#   {'aspect': 'dress', 'opinion': ' casual'}],
#  [{'aspect': 'print', 'opinion': ' different'},
#   {'aspect': 'skirt', 'opinion': ' full'},
#   {'aspect': 'size', 'opinion': ' perfect'},
#   {'aspect': 'sleeves', 'opinion': ' easy'}],
#  [{'aspect': 'zipper', 'opinion': ' side'},
#   {'aspect': 'dress', 'opinion': ' entire'}],
#  [{'aspect': 'pattern', 'opinion': 'super cute'}],
#  [{'aspect': 'tie', 'opinion': 'really difficult'}],
#  [{'aspect': 'tie', 'opinion': ' afraid'}],
#  [],
#  [{'aspect': 'amount', 'opinion': ' right'},
#   {'aspect': 'cons', 'opinion': ' only'}],
#  [],
#  [],
#  [{'aspect': 'reviewers', 'opinion': ' other'},
#   {'aspect': 'quality', 'opinion': 'really nice'},
#   {'aspect': 'fabric', 'opinion': ' nice'}],
#  [{'aspect': 'length', 'opinion': ' regular'}],
#  [{'aspect': 'bra', 'opinion': ' great'}],
#  [{'aspect': 'xxs', 'opinion': 'usually looser'},
#   {'aspect': 'waist', 'opinion': ' comfortable'},
#   {'aspect': 'part', 'opinion': ' weird'},
#   {'aspect': 'part', 'opinion': ' lighter'},
#   {'aspect': 'part', 'opinion': ' softer'}],
#  [],
#  [{'aspect': 'weight', 'opinion': ' graceful'},
#   {'aspect': 'cut', 'opinion': ' loose'}],
#  [{'aspect': 'number', 'opinion': ' lovely'},
#   {'aspect': 'fabric', 'opinion': ' flattering'},
#   {'aspect': 'pattern', 'opinion': ' neutral'}],
#  [],
#  [],
#  [{'aspect': 'fabric', 'opinion': ' dreamy'}],
#  [{'aspect': 'back', 'opinion': ' adorable'},
#   {'aspect': 'retailer', 'opinion': 'too late'}],
#  [{'aspect': 'thing', 'opinion': ' only'}],
#  [{'aspect': 'length', 'opinion': 'so awkward'}],
#  [],
#  [{'aspect': 'design', 'opinion': ' classy'}],
#  [{'aspect': 'strops', 'opinion': ' elastic'},
#   {'aspect': 'ties', 'opinion': ' different'}],
#  [],
#  [{'aspect': 'medium', 'opinion': ' correct'}],
#  [{'aspect': 'dress', 'opinion': ' fantastic'}],
#  [],
#  [{'aspect': 'dress', 'opinion': 'so comfortable'},
#   {'aspect': 'weather', 'opinion': 'often warm'}],
#  [{'aspect': 'dress', 'opinion': ' lovely'},
#   {'aspect': 'dress', 'opinion': 'then soft'},
#   {'aspect': 'complaint', 'opinion': ' only'},
#   {'aspect': 'dress', 'opinion': ' true'}],
#  [{'aspect': 'material', 'opinion': 'so flimsy'}],
#  [{'aspect': 'dress', 'opinion': ' perfect'}],
#  [{'aspect': 'petite', 'opinion': 'only few'},
#   {'aspect': 'color', 'opinion': ' neutral'},
#   {'aspect': 'thin-ish', 'opinion': 'super comfortable'}],
#  [{'aspect': 'reviewers', 'opinion': ' other'},
#   {'aspect': 'balance', 'opinion': ' nice'},
#   {'aspect': 'fit', 'opinion': 'still opaque'}],
#  [],
#  [{'aspect': 'front', 'opinion': 'too tiny'},
#   {'aspect': 'tuck', 'opinion': 'just odd'}],
#  [],
#  [{'aspect': 'dress', 'opinion': 'so flattering'}],
#  [{'aspect': 'dress', 'opinion': ' new'},
#   {'aspect': 'stores', 'opinion': ' more'}],
#  [{'aspect': 'colors', 'opinion': 'so many'},
#   {'aspect': 'sale', 'opinion': ' full'},
#   {'aspect': 'winner', 'opinion': 'online clear'},
#   {'aspect': 'prints', 'opinion': 'all great'},
#   {'aspect': 'dresses', 'opinion': 'so flattering'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' great'},
#   {'aspect': 'fabric', 'opinion': ' light'},
#   {'aspect': 'finishing', 'opinion': ' moderate'}],
#  [],
#  [{'aspect': 'fit', 'opinion': 'so excited'}],
#  [{'aspect': 'fact', 'opinion': ' washable'},
#   {'aspect': 'fabric', 'opinion': 'so comfortable'},
#   {'aspect': 'length', 'opinion': ' perfect'}],
#  [{'aspect': 'holes', 'opinion': 'too upper'},
#   {'aspect': 'reviewer', 'opinion': ' big'},
#   {'aspect': 'dress', 'opinion': ' long'}],
#  [{'aspect': 'waist', 'opinion': 'only minor'},
#   {'aspect': 'sides', 'opinion': 'almost white'}],
#  [{'aspect': 'fabric', 'opinion': ' soft'},
#   {'aspect': 'weather', 'opinion': ' warmer'}],
#  [{'aspect': 'half', 'opinion': ' bottom'},
#   {'aspect': 'medium', 'opinion': ' fine'},
#   {'aspect': 'waist', 'opinion': ' long'}],
#  [],
#  [{'aspect': 'material', 'opinion': ' flattering'}],
#  [{'aspect': 'dress', 'opinion': ' gorgeous'},
#   {'aspect': 'fabric', 'opinion': ' big'}],
#  [{'aspect': 'fit', 'opinion': 'incredibly flattering'},
#   {'aspect': 'fabric', 'opinion': ' lovely'},
#   {'aspect': 'xl', 'opinion': ' looser'},
#   {'aspect': 'back', 'opinion': ' low'}],
#  [{'aspect': 'dress', 'opinion': ' amazing'},
#   {'aspect': 'm', 'opinion': ' perfect'}],
#  [],
#  [{'aspect': 'medium', 'opinion': ' muscular'}],
#  [{'aspect': 'cut', 'opinion': 'really true'},
#   {'aspect': 'sizing', 'opinion': ' straightforward'},
#   {'aspect': 'xxsp', 'opinion': ' regular'}],
#  [{'aspect': 'dress', 'opinion': ' flattering'},
#   {'aspect': 'sizing', 'opinion': ' perfect'}],
#  [],
#  [],
#  [],
#  [{'aspect': 'tangerine', 'opinion': 'online red'},
#   {'aspect': 'color', 'opinion': 'actually deep'},
#   {'aspect': 'fabric', 'opinion': 'super comfortable'},
#   {'aspect': 'problem', 'opinion': ' only'},
#   {'aspect': 'top', 'opinion': 'too large'}],
#  [],
#  [{'aspect': 'back', 'opinion': ' nice'}],
#  [{'aspect': 'dress', 'opinion': ' soft'}],
#  [{'aspect': 'color', 'opinion': ' beautiful'},
#   {'aspect': 'fit', 'opinion': ' flattering'}],
#  [{'aspect': 'petite', 'opinion': ' little'}],
#  [{'aspect': 'dress', 'opinion': 'very comfortable'}],
#  [{'aspect': 'scoop', 'opinion': 'especially soft'},
#   {'aspect': 'print', 'opinion': 'very white'},
#   {'aspect': 'sizing', 'opinion': ' little'},
#   {'aspect': 'length', 'opinion': ' perfect'},
#   {'aspect': 'waist', 'opinion': ' little'},
#   {'aspect': 'seam', 'opinion': ' top'},
#   {'aspect': 'seam', 'opinion': ' bottom'}],
#  [],
#  [{'aspect': 'length', 'opinion': 'pretty tall'},
#   {'aspect': 'back', 'opinion': ' low'}],
#  [],
#  [{'aspect': 'part', 'opinion': 'occasionally top'},
#   {'aspect': 'sleeves', 'opinion': ' low'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' small'},
#   {'aspect': 'holes', 'opinion': ' large'},
#   {'aspect': 'dress', 'opinion': ' other'}],
#  [{'aspect': 'material', 'opinion': ' Beautiful'}],
#  [],
#  [{'aspect': 'neckline', 'opinion': ' little'},
#   {'aspect': 'straps', 'opinion': ' front'}],
#  [{'aspect': 'straps', 'opinion': ' adjustable'},
#   {'aspect': 'dress', 'opinion': 'too low'},
#   {'aspect': 'belt', 'opinion': 'very thin'},
#   {'aspect': 's', 'opinion': 'usually perfect'},
#   {'aspect': 'dress', 'opinion': 'so flawless'}],
#  [{'aspect': 'dress', 'opinion': 'too much'},
#   {'aspect': 'material', 'opinion': 'really soft'}],
#  [{'aspect': 'colors', 'opinion': ' vibrant'}],
#  [{'aspect': 'armholes', 'opinion': 'so overwhelming'},
#   {'aspect': 'colors', 'opinion': ' nice'},
#   {'aspect': 'fabric', 'opinion': ' soft'},
#   {'aspect': 'length', 'opinion': ' good'}],
#  [],
#  [{'aspect': 'mother', 'opinion': ' blue'}],
#  [{'aspect': 'material', 'opinion': ' rich'}],
#  [],
#  [{'aspect': 'reviewer', 'opinion': ' huge'},
#   {'aspect': 'boobs', 'opinion': 'also ok'},
#   {'aspect': 'photos', 'opinion': 'definitely more'},
#   {'aspect': 'dress', 'opinion': ' pregnant'}],
#  [{'aspect': 'pattern', 'opinion': 'very nice'},
#   {'aspect': 'fabric', 'opinion': 'too much'}],
#  [{'aspect': 'fabric', 'opinion': ' beautiful'},
#   {'aspect': 'dress', 'opinion': ' most'},
#   {'aspect': 'length', 'opinion': ' huge'},
#   {'aspect': 'dress', 'opinion': ' perfect'},
#   {'aspect': 'boyfriend', 'opinion': ' pregnan'}],
#  [],
#  [],
#  [{'aspect': 'reviewer', 'opinion': ' essential'}],
#  [{'aspect': 'colors', 'opinion': 'so fun'}],
#  [{'aspect': 'dress', 'opinion': ' style'},
#   {'aspect': 'dress', 'opinion': ' beautiful'}],
#  [{'aspect': 'dress', 'opinion': ' soft'}],
#  [{'aspect': 'fabric', 'opinion': ' soft'}],
#  [{'aspect': 'fabric', 'opinion': 'too bunchy'}],
#  [],
#  [{'aspect': 'reviewers', 'opinion': ' other'},
#   {'aspect': 'straps', 'opinion': 'usually adjustable'},
#   {'aspect': 'part', 'opinion': 'so top'},
#   {'aspect': 'material', 'opinion': 'so much'},
# ...
#   {'aspect': '2p', 'opinion': ' fine'}],
#  [],
#  [{'aspect': '0p', 'opinion': 'too small'},
#   {'aspect': 'pattern', 'opinion': ' flattering'}],
#  [{'aspect': 'bust', 'opinion': 'not other'},
#   {'aspect': 'dress', 'opinion': 'fortunately blue'},
#   {'aspect': 'dress', 'opinion': 'perfectly many'}],
#  [{'aspect': 'petite', 'opinion': ' lovely'},
#   {'aspect': '4p', 'opinion': ' perfect'}],
#  [{'aspect': 'skirt', 'opinion': ' top'},
#   {'aspect': 'quality', 'opinion': ' good'},
#   {'aspect': 'areas', 'opinion': ' floral'},
#   {'aspect': 'details', 'opinion': ' little'}],
#  [{'aspect': 'portion', 'opinion': ' little'},
#   {'aspect': 'length', 'opinion': 'just knee'}],
#  [{'aspect': 'dress', 'opinion': 'pretty real'},
#   {'aspect': 'back', 'opinion': 'very low'},
#   {'aspect': 'way', 'opinion': 'much tighter'}],
#  [{'aspect': 'color', 'opinion': ' blue'},
#   {'aspect': 'overlay', 'opinion': ' lovely'},
#   {'aspect': 'flare', 'opinion': "i'm lower"},
#   {'aspect': 'size', 'opinion': ' petite'},
#   {'aspect': 'size', 'opinion': ' regular'},
#   {'aspect': 'waistband', 'opinion': 'more flattering'}],
#  [{'aspect': 'combo', 'opinion': ' unique'}],
#  [],
#  [{'aspect': 'dress', 'opinion': 'even better'},
#   {'aspect': 'fabric', 'opinion': 'very delicate'},
#   {'aspect': 'fit', 'opinion': ' perfect'}],
#  [{'aspect': 'dress', 'opinion': ' first'},
#   {'aspect': 'dress', 'opinion': 'online true'},
#   {'aspect': 'zipper', 'opinion': 'super cheap'}],
#  [{'aspect': 'one', 'opinion': ' beauty'},
#   {'aspect': 'store', 'opinion': ' white'},
#   {'aspect': 'shot', 'opinion': ' top'},
#   {'aspect': 'details', 'opinion': ' lovely'}],
#  [{'aspect': 'fabric', 'opinion': 'sickly yellow'},
#   {'aspect': 'fabric', 'opinion': ' plus'}],
#  [],
#  [{'aspect': 'color', 'opinion': 'so blue'},
#   {'aspect': 'one', 'opinion': ' blue'}],
#  [],
#  [{'aspect': 'people', 'opinion': ' many'}],
#  [{'aspect': 'fabric', 'opinion': ' soft'},
#   {'aspect': 'shape', 'opinion': ' basic'}],
#  [],
#  [{'aspect': 'detail', 'opinion': ' beautiful'},
#   {'aspect': 'edging', 'opinion': ' unfinished'},
#   {'aspect': 'angle', 'opinion': 'even bigger'},
#   {'aspect': 'pleating', 'opinion': 'very cute'}],
#  [],
#  [{'aspect': 'design', 'opinion': ' perfect'},
#   {'aspect': 'material', 'opinion': ' little'},
#   {'aspect': 'lining', 'opinion': ' substantial'},
#   {'aspect': 'waist', 'opinion': 'somewhat broad'}],
#  [{'aspect': 'quality', 'opinion': ' nice'},
#   {'aspect': 'zipper', 'opinion': ' classy'}],
#  [{'aspect': 'detail', 'opinion': ' bottom'}],
#  [{'aspect': 'size', 'opinion': ' larger'}],
#  [{'aspect': 'fringe', 'opinion': 'so special'}],
#  [{'aspect': 'fit', 'opinion': ' perfect'},
#   {'aspect': 'area', 'opinion': 'however striped'},
#   {'aspect': 'stripes', 'opinion': ' white'}],
#  [{'aspect': 'colors', 'opinion': 'Just beautiful'},
#   {'aspect': 'fabric', 'opinion': 'very soft'},
#   {'aspect': 'detail', 'opinion': ' nice'}],
#  [{'aspect': 'dress', 'opinion': ' true'},
#   {'aspect': 'buttons', 'opinion': ' nice'},
#   {'aspect': 'dress', 'opinion': ' tall'}],
#  [{'aspect': 'dress', 'opinion': 'even better'},
#   {'aspect': 'colors', 'opinion': ' vibrant'},
#   {'aspect': 'material', 'opinion': ' nice'},
#   {'aspect': 'buttons', 'opinion': ' warm'},
#   {'aspect': 'dress', 'opinion': 'only extra'},
#   {'aspect': 'dress', 'opinion': ' little'}],
#  [{'aspect': 'dress', 'opinion': 'very beautiful'},
#   {'aspect': 'colors', 'opinion': 'very fall'}],
#  [{'aspect': 'dress', 'opinion': ' beautiful'}],
#  [{'aspect': 'armholes', 'opinion': 'totally bizarre'},
#   {'aspect': 'one', 'opinion': ' else'},
#   {'aspect': 'armholes', 'opinion': 'so long'},
#   {'aspect': 'dress', 'opinion': 'really broad'}],
#  [{'aspect': 'ladies', 'opinion': ' large-chested'}],
#  [{'aspect': 'dress', 'opinion': ' perfect'}],
#  [{'aspect': 'shape', 'opinion': ' a-line'},
#   {'aspect': 'pattern', 'opinion': 'very retro'},
#   {'aspect': 'side', 'opinion': ' only'},
#   {'aspect': 'dress', 'opinion': ' other'}],
#  [{'aspect': 'colors', 'opinion': ' great'},
#   {'aspect': 'style', 'opinion': ' cute'}],
#  [{'aspect': 'colors', 'opinion': ' warm'},
#   {'aspect': 'length', 'opinion': 'so regular'},
#   {'aspect': 'sp', 'opinion': 'unfortunately enormous'}],
#  [{'aspect': 'dress', 'opinion': ' beautiful'},
#   {'aspect': 'issue', 'opinion': ' only'},
#   {'aspect': 'medium', 'opinion': 'normally large'}],
#  [{'aspect': 'dresses', 'opinion': ' uniform'},
#   {'aspect': 'patterns', 'opinion': 'particularly unique'},
#   {'aspect': 'one', 'opinion': 'swiftly full'}],
#  [{'aspect': 'quality', 'opinion': 'very comfortable'},
#   {'aspect': 'boots', 'opinion': ' nice'},
#   {'aspect': 'set', 'opinion': ' high'}],
#  [{'aspect': 'dress', 'opinion': ' large'}],
#  [{'aspect': 'one', 'opinion': ' same'},
#   {'aspect': 'dresses', 'opinion': 'why regular'},
#   {'aspect': 'print', 'opinion': ' gorgeous'}],
#  [],
#  [{'aspect': 'fit', 'opinion': 'otherwise fine'},
#   {'aspect': 'cut', 'opinion': ' great'}],
#  [{'aspect': 'colors', 'opinion': ' great'},
#   {'aspect': 'holes', 'opinion': ' little'}],
#  [{'aspect': 'dress', 'opinion': 'slightly line'},
#   {'aspect': 'xl', 'opinion': 'even flattering'},
#   {'aspect': 'arms', 'opinion': 'definitely smaller'},
#   {'aspect': 'button', 'opinion': 'too tight'}],
#  [{'aspect': 'price', 'opinion': ' high'},
#   {'aspect': 'quality', 'opinion': 'super comfortable'},
#   {'aspect': 'material', 'opinion': ' soft'},
#   {'aspect': 'dress', 'opinion': ' fabulous'}],
#  [{'aspect': 'colors', 'opinion': ' stunning'},
#   {'aspect': 'dress', 'opinion': 'usually large'}],
#  [{'aspect': "i'm", 'opinion': 'always petite'},
#   {'aspect': 'petite', 'opinion': 'exceptionally small'},
#   {'aspect': 'pm', 'opinion': 'too big'}],
#  [{'aspect': 'dresses', 'opinion': ' amazing'},
#   {'aspect': 'colors', 'opinion': ' happy'},
#   {'aspect': 'complaint', 'opinion': ' little'}],
#  [],
#  [{'aspect': 'dress', 'opinion': 'much other'},
#   {'aspect': 'cut', 'opinion': 'way armpit'},
#   {'aspect': 'amount', 'opinion': ' worth'},
#   {'aspect': 'thing', 'opinion': 'so cold'}],
#  [{'aspect': 'tape', 'opinion': 'usually double'}],
#  [{'aspect': 'dress', 'opinion': ' worth'}],
#  [{'aspect': 'color', 'opinion': ' blue'}],
#  [],
#  [{'aspect': 'color', 'opinion': 'also blue'}],
#  [{'aspect': 'dress', 'opinion': 'So interesting'},
#   {'aspect': 'petite', 'opinion': ' sexy'},
#   {'aspect': 'rest', 'opinion': 'really odd'}],
#  [{'aspect': 'dress', 'opinion': 'extremely flattering'},
#   {'aspect': 'cut', 'opinion': 'nicely true'},
#   {'aspect': 'xxsp', 'opinion': ' tall'},
#   {'aspect': 'dress', 'opinion': ' lovely'}],
#  [{'aspect': 'plunge', 'opinion': 'too deep'},
#   {'aspect': 'color', 'opinion': ' blue'},
#   {'aspect': 'front', 'opinion': ' flattering'}],
#  [{'aspect': "'", 'opinion': ' petite'}],
#  [{'aspect': 'supper', 'opinion': ' flattering'}],
#  [{'aspect': 'fit', 'opinion': ' good'},
#   {'aspect': 'material', 'opinion': ' beautiful'},
#   {'aspect': 'length', 'opinion': ' delightful'},
#   {'aspect': 'pattern', 'opinion': ' fun'}],
#  [],
#  [],
#  [{'aspect': 'dress', 'opinion': 'very flattering'},
#   {'aspect': 'dress', 'opinion': 'fairly not-so-small'}],
#  [{'aspect': 'length', 'opinion': ' fine'}],
#  [{'aspect': 'length', 'opinion': 'somewhat awkward'}],
#  [{'aspect': 'dress', 'opinion': 'really elegant'},
#   {'aspect': 'bust', 'opinion': ' wide'},
#   {'aspect': 'dress', 'opinion': 'fairly straight'},
#   {'aspect': 'length', 'opinion': ' regular'}],
#  [{'aspect': 'dress', 'opinion': ' perfect'}],
#  [{'aspect': 'dress', 'opinion': ' gorgeous'},
#   {'aspect': 'flaw', 'opinion': ' only'},
#   {'aspect': 'armholes', 'opinion': ' little'},
#   {'aspect': 'bra', 'opinion': 'not enough'}],
#  [{'aspect': 'pattern', 'opinion': ' visual'}],
#  [{'aspect': 'dress', 'opinion': 'way better'},
#   {'aspect': 'design', 'opinion': 'very skinny'},
#   {'aspect': 'length', 'opinion': 'also perfect'}],
#  [{'aspect': 'print', 'opinion': ' lovely'}],
#  [{'aspect': 'xs', 'opinion': 'so kind'}],
#  [{'aspect': 'print', 'opinion': ' turquoise'}],
#  [{'aspect': 'dress', 'opinion': 'more adorable'},
#   {'aspect': 'material', 'opinion': ' right'},
#   {'aspect': 'dress', 'opinion': 'so adorable'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' great'},
#   {'aspect': 'center', 'opinion': ' nice'}],
#  [{'aspect': 'dress', 'opinion': 'more stunning'}],
#  [],
#  [{'aspect': 'dress', 'opinion': 'very comfortable'},
#   {'aspect': 'critique', 'opinion': ' only'},
#   {'aspect': 'skirt', 'opinion': ' more'},
#   {'aspect': 'bodice', 'opinion': 'more peach'},
#   {'aspect': 'm', 'opinion': ' great'}],
#  [{'aspect': 'dress', 'opinion': "i'm lean"},
#   {'aspect': 'top', 'opinion': 'firstly strange'},
#   {'aspect': 'bunching', 'opinion': 'less clean'}],
#  [],
#  [{'aspect': 'design', 'opinion': ' cute'},
#   {'aspect': 'construction', 'opinion': ' little'},
#   {'aspect': 'transition', 'opinion': ' wrong'},
#   {'aspect': 'bottom', 'opinion': 'very thin'}],
#  [{'aspect': 'part', 'opinion': 'so top'}],
#  [{'aspect': 'dress', 'opinion': 'first beautiful'}],
#  [],
#  [{'aspect': 'fabric', 'opinion': 'so flattering'}],
#  [{'aspect': 'fit', 'opinion': ' fantastic'}],
#  [{'aspect': 'dress', 'opinion': ' much'},
#   {'aspect': 'dress', 'opinion': 'just curvy'},
#   {'aspect': 'maeve', 'opinion': ' great'}],
#  [{'aspect': 'dress', 'opinion': 'simply gorgeous'},
#   {'aspect': 'slit', 'opinion': 'just right'},
#   {'aspect': 'colors', 'opinion': ' great'}],
#  [{'aspect': 'colors', 'opinion': ' neutral'},
#   {'aspect': 'petites', 'opinion': 'unfortunately available'}],
#  [{'aspect': 'reviewers', 'opinion': 'however other'},
#   {'aspect': 'transition', 'opinion': ' extra'},
#   {'aspect': 'weight', 'opinion': 'there little'},
#   {'aspect': 'fold', 'opinion': ' extra'}],
#  [{'aspect': 'skirt', 'opinion': 'still great'},
#   {'aspect': 'top', 'opinion': ' great'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' gorgeous'}],
#  [{'aspect': 'colors', 'opinion': ' nice'},
#   {'aspect': 'dress', 'opinion': 'otherwise nice'},
#   {'aspect': 'price', 'opinion': ' right'}],
#  [{'aspect': 'cut', 'opinion': 'too hippy'}],
#  [],
#  [{'aspect': 'colors', 'opinion': ' beautiful'},
#   {'aspect': 'fabric', 'opinion': 'very soft'},
#   {'aspect': 'length', 'opinion': 'so shorter'}],
#  [{'aspect': 'dress', 'opinion': ' true'},
#   {'aspect': 'uses', 'opinion': 'so many'},
#   {'aspect': 'brand', 'opinion': 'always great'}],
#  [{'aspect': 'dress', 'opinion': ' perfect'},
#   {'aspect': 'material', 'opinion': 'super soft'}],
#  [{'aspect': 'dress', 'opinion': 'perfectly flowy'},
#   {'aspect': 'band', 'opinion': 'also elastic'}],
#  [],
#  [],
#  [{'aspect': 'fabric', 'opinion': 'more heavy'}],
#  [],
#  [{'aspect': 'slits', 'opinion': ' higher'}],
#  [{'aspect': 'bottom', 'opinion': 'all dirty'},
#   {'aspect': 'dress', 'opinion': ' other'}],
#  [{'aspect': 'waist', 'opinion': ' higher'}],
#  [{'aspect': 'dress', 'opinion': 'super flattering'},
#   {'aspect': 'fabric', 'opinion': ' criss-crossing'},
#   {'aspect': 'fabric', 'opinion': ' little'},
#   {'aspect': 'skirt', 'opinion': ' light'},
#   {'aspect': 'pattern', 'opinion': ' airy'}],
#  [{'aspect': 'motif', 'opinion': ' one'},
#   {'aspect': 'inside', 'opinion': ' white'},
#   {'aspect': 'dresses', 'opinion': ' favorite'},
#   {'aspect': 'petite', 'opinion': 'too large'}],
#  [{'aspect': 'bodice', 'opinion': ' new'},
#   {'aspect': 'material', 'opinion': ' true'},
#   {'aspect': 'fabric', 'opinion': ' thin'},
#   {'aspect': 'look', 'opinion': ' overall'},
#   {'aspect': 'maxis', 'opinion': ' better'}],
#  [],
#  [{'aspect': 'material', 'opinion': 'however great'}],
#  [],
#  [{'aspect': 'wish', 'opinion': "i'm only"},
#   {'aspect': 'dress', 'opinion': ' less'}],
#  [{'aspect': 'xs', 'opinion': ' large'}],
#  [{'aspect': 'dress', 'opinion': ' perfect'},
#   {'aspect': 'color', 'opinion': ' blue'},
#   {'aspect': 'ruching', 'opinion': 'just itchy'}],
#  [{'aspect': 'dress', 'opinion': 'overall nice'}],
#  [{'aspect': 'catch', 'opinion': ' right'},
#   {'aspect': 'fabric', 'opinion': 'so large'}],
#  [{'aspect': 'dress', 'opinion': 'normally large'},
#   {'aspect': 'small', 'opinion': 'too big'}],
#  [{'aspect': 'clerk', 'opinion': ' large'}],
#  [],
#  [],
#  [{'aspect': 'dress', 'opinion': 'really huge'},
#   {'aspect': 'material', 'opinion': ' nice'},
#   {'aspect': 'shape', 'opinion': 'really good'}],
#  [{'aspect': 'day', 'opinion': 'already several'}],
#  [{'aspect': 'dress', 'opinion': 'back great'},
#   {'aspect': 'lining', 'opinion': 'super flattering'},
#   {'aspect': 'fabric', 'opinion': ' sweet'},
#   {'aspect': 'gathering', 'opinion': ' floral'},
#   {'aspect': 'back', 'opinion': 'just flattering'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' huge'}],
#  [],
#  [],
#  [{'aspect': 'quality', 'opinion': ' edgy'}],
#  [{'aspect': 'dress', 'opinion': ' normal'},
#   {'aspect': 'reviewer', 'opinion': 'first perfect'},
#   {'aspect': 'husband', 'opinion': ' many'}],
#  [{'aspect': 'waist', 'opinion': ' elastic'},
#   {'aspect': 'slip', 'opinion': 'too inner'},
#   {'aspect': 'reviewer', 'opinion': ' tiny'},
#   {'aspect': 'slip', 'opinion': ' adjustable'}],
#  [],
#  [{'aspect': 'fit', 'opinion': ' fabulous'},
#   {'aspect': 'complaint', 'opinion': ' only'},
#   {'aspect': 'one', 'opinion': 'slightly defective'}],
#  [{'aspect': 's', 'opinion': 'really vibrant'},
#   {'aspect': 'women', 'opinion': ' smaller'}],
#  [],
#  [],
#  [{'aspect': 'fabric', 'opinion': ' great'}],
#  [{'aspect': 'cut', 'opinion': 'perfectly big'},
#   {'aspect': 'neckline', 'opinion': 'pretty small'},
#   {'aspect': 'plan', 'opinion': 'yet sure'}],
#  [{'aspect': 'skirt', 'opinion': ' flouncy'}],
#  [{'aspect': 'fabric', 'opinion': ' Beautiful'}],
#  [{'aspect': 'top', 'opinion': 'still tad'}],
#  [{'aspect': 'dress', 'opinion': 'so perfect'},
#   {'aspect': 'skirt', 'opinion': 'too much'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' comfortable'}],
#  [],
#  [{'aspect': 'dress', 'opinion': ' awesome'}],
#  [{'aspect': 'skirt', 'opinion': 'very tiny'},
#   {'aspect': 'fabric', 'opinion': ' wide'},
#   {'aspect': 'colors', 'opinion': 'very soft'}],
#  [{'aspect': 'dress', 'opinion': ' else'},
#   {'aspect': 'dress', 'opinion': 'so perfect'},
#   {'aspect': 'bodice', 'opinion': ' bigger'},
#   {'aspect': 'silhouette', 'opinion': ' odd'},
#   {'aspect': 'fabric', 'opinion': ' gorgeous'}],
#  [{'aspect': 'print', 'opinion': 'alas adorable'},
#   {'aspect': 'skirt', 'opinion': ' pleated'},
#   {'aspect': 'neckline', 'opinion': 'too full'}],
#  [{'aspect': 'design', 'opinion': 'yet beautiful'}],
#  [],
#  [{'aspect': 'line', 'opinion': ' little'}],
#  [{'aspect': 'material', 'opinion': ' awesome'}],
#  [{'aspect': 'color', 'opinion': ' darker'},
#   {'aspect': 'lining', 'opinion': ' hot'}],
#  [{'aspect': 'shape', 'opinion': ' good'},
#   {'aspect': 'cut', 'opinion': 'still flattering'},
#   {'aspect': 'fabric', 'opinion': ' outer'},
#   {'aspect': 'lining', 'opinion': 'very sheer'}],
#  [{'aspect': 'pattern', 'opinion': 'so beautiful'},
#   {'aspect': 'lot', 'opinion': ' loose'},
#   {'aspect': 'complaint', 'opinion': 'also only'},
#   {'aspect': 'slip', 'opinion': 'usually little'}],
#  [{'aspect': 'length', 'opinion': ' slim'},
#   {'aspect': 'size', 'opinion': ' boxy'}],
#  [{'aspect': 'dress', 'opinion': ' inner'},
#   {'aspect': 'collar', 'opinion': ' unique'},
#   {'aspect': 'cat', 'opinion': ' yucky'}],
#  [{'aspect': 'print', 'opinion': 'so elegant'},
#   {'aspect': 'colors', 'opinion': 'too vibrant'},
#   {'aspect': 'collar', 'opinion': ' french'},
#   {'aspect': 'dress', 'opinion': ' little'}],
#  [{'aspect': 'print', 'opinion': ' face'},
#   {'aspect': 'collar', 'opinion': 'slightly past'},
#   {'aspect': 'fabric', 'opinion': ' extra'}],
#  [{'aspect': 'dress', 'opinion': 'much prettier'}],
#  [{'aspect': 'material', 'opinion': ' high'},
#   {'aspect': 'fit', 'opinion': ' true'}],
#  [{'aspect': 'dress', 'opinion': ' beautiful'}],
#  [{'aspect': 'embroidery', 'opinion': ' beautiful'},
#   {'aspect': 'complaint', 'opinion': ' only'}],
#  [{'aspect': 'fabric', 'opinion': 'very flattering'},
#   {'aspect': 'lining', 'opinion': 'much smaller'},
#   {'aspect': 'linings', 'opinion': ' many'},
#   {'aspect': 'reviewers', 'opinion': ' other'}],
#  [{'aspect': 'detail', 'opinion': ' exquisite'}],
#  [{'aspect': 'fabric', 'opinion': ' thin'},
#   {'aspect': 'photo', 'opinion': ' least'}],
#  [{'aspect': 'material', 'opinion': ' high'}]]

# %%
# joining aspects with opinions to create meaningful labels
paragraph,sentence=[],[]
for para in parag_aspects:
    for asp in para:
#         print(asp)
        label = '-'.join(asp.values())
        sentence.append(label)
    paragraph.append(sentence)
    sentence=[]

# %%
df['aspect-opinion']=paragraph

# %%
df[['Review Text','aspect-opinion']]
# Out:
#                                              Review Text  \
# 54     I really wanted this to work. alas, it had a s...
# 71     I love cute summer dresses and this one, espec...
# 374    Nice fit and flare style, not clingy at all. i...
# 377    When i first opened this dress and tried it on...
# 381    I love this sweater dress and get compliments ...
# ...                                                  ...
# 19256  I love this dress. i agree with the other revi...
# 19261  Beautiful, unique design. it's very flattering...
# 19266  This is the most beautiful dress i've ever own...
# 19651  I purchased this for a very good price and i t...
# 19656  I bought this dress for work and post work hap...
#
#                                           aspect-opinion
# 54                    [straps- weird, fabric- beautiful]
# 71                  [one- cute, material-well difficult]
# 374                                       [petite- grey]
# 377                                       [problem- hem]
# 381    [pattern-just fun, skirt- flattering, material...
# ...                                                  ...
# 19256           [embroidery- beautiful, complaint- only]
# 19261  [fabric-very flattering, lining-much smaller, ...
# 19266                                [detail- exquisite]
# 19651                       [fabric- thin, photo- least]
# 19656                                   [material- high]
#
# [871 rows x 2 columns]

# %%
#extracting aspects and opinions for each row.
# para_aspects,sent_aspects = [],[]
# para_opinions,sent_opinions = [],[]
# for para in parag_aspects:
#     for asp in para:
#         sent_aspects.append(asp['aspect'])
#         sent_opinions.append(asp['opinion'])
#     para_aspects.append(sent_aspects)
#     para_opinions.append(sent_opinions)
#     sent_aspects=[]
#     sent_opinions=[]

# %%
# df['aspects'] = para_aspects

# %%
# df['opinions'] = para_opinions

# %%
#combining dict's aspect-values and appending opinion-values to gain insights about each aspect.
from collections import defaultdict
d=defaultdict(list)
for para in parag_aspects:
    for dictn in para:
        d[dictn['aspect']].append(dictn['opinion'])

# %%
d
# Out:
# defaultdict(list,
#             {'straps': [' weird',
#               ' front',
#               ' adjustable',
#               'usually adjustable'],
#              'fabric': [' beautiful',
#               ' thick',
#               ' Comfortable',
#               'very soft',
#               ' buttery',
#               ' heavy',
#               'so much',
#               'so disappointed',
#               ' other',
#               'simply gorgeous',
#               'quite soft',
#               ' lower',
#               ' high',
#               ' best',
#               ' soft',
#               ' substantial',
#               'very stiff',
#               ' thin',
#               ' nice',
#               ' thin',
#               'quite loose',
#               'still weird',
#               'very soft',
#               ' soft',
#               ' light',
#               ' lovely',
#               'too much',
#               'absolutely gorgeous',
#               'too much',
#               ' thin',
#               'very stiff',
#               ' maroon',
#               ' crepe',
#               ' high',
#               'so light',
#               ' opaque',
#               ' sheer',
#               ' necessary',
#               ' soft',
#               ' lightweight',
#               ' blue',
#               ' same',
#               'too hot',
#               ' rustic',
#               'so much',
#               ' thick',
#               'so cute',
#               'pretty cute',
#               ' nice',
#               ' flattering',
#               ' dreamy',
#               ' light',
#               'so comfortable',
#               ' soft',
#               ' big',
#               ' lovely',
#               'super comfortable',
#               ' soft',
#               'too much',
#               ' beautiful',
#               ' soft',
#               'too bunchy',
#               'maybe excess',
#               'very gentle',
#               ' gorgeous',
#               'very unflattering',
#               ' nice',
#               ' fine',
#               'very gorgeous',
#               'so beautiful',
#               'nicely baggy',
#               'also different',
#               ' beautiful',
#               ' stiff',
#               'too much',
#               ' amazing',
#               ' little',
#               ' big',
#               ' gorgeous',
#               ' light',
#               'closely medical',
#               'very delicate',
#               'sickly yellow',
#               ' plus',
#               ' soft',
#               'very soft',
#               'so flattering',
#               'very soft',
#               'more heavy',
#               ' criss-crossing',
#               ' little',
#               ' thin',
#               'so large',
#               ' sweet',
#               ' great',
#               ' Beautiful',
#               ' wide',
#               ' gorgeous',
#               ' outer',
#               ' extra',
#               'very flattering',
#               ' thin'],
#              'one': [' cute',
#               ' grey',
#               'super comfortable',
#               'potentially negative',
#               'too full',
#               ' turquoise',
#               ' colorful',
#               'nearly impossible',
#               'too billowy',
#               'pretty big',
#               'often same',
#               'only smaller',
#               'really cute',
#               'sometimes regular',
#               'too snug',
#               ' beauty',
#               ' blue',
#               ' else',
#               'swiftly full',
#               ' same',
#               'slightly defective'],
#              'material': ['well difficult',
#               'too heavy',
#               ' great',
#               ' appropriate',
#               'so stunning',
#               'very soft',
#               ' stretchy',
#               'very nice',
#               ' over',
#               'as bright',
#               'even rough',
#               ' high',
#               'extremely comfortable',
#               ' little',
#               ' soft',
#               'just thin',
#               ' soft',
#               'very thick',
#               ' light',
#               ' white',
#               'so soft',
#               'very soft',
#               ' sure',
#               ' iridescent',
#               ' less',
#               ' substantial',
#               ' thick',
#               ' poofy',
#               ' beautiful',
#               ' polyester',
#               ' soft',
#               'well nice',
#               'very thin',
#               ' substantial',
#               ' little',
#               ' cheap',
#               ' adorable',
#               'so flimsy',
#               ' flattering',
#               ' Beautiful',
#               'really soft',
#               ' rich',
#               'so much',
#               'so bummed',
#               ' soft',
#               'really fake',
#               ' heavier',
#               ' heavier',
#               'perfectly buttery',
#               ' thicker',
#               ' little',
#               ' nice',
#               ' soft',
#               ' beautiful',
#               ' right',
#               'super soft',
#               ' true',
#               'however great',
#               ' nice',
#               ' awesome',
#               ' high',
#               ' high'],
#              'petite': [' grey',
#               'only few',
#               ' little',
#               'too high',
#               ' lovely',
#               'exceptionally small',
#               ' sexy',
#               'too large'],
#              'problem': [' hem',
#               ' only',
#               ' sleeves',
#               'then larger',
#               ' only',
#               ' only',
#               ' biggest',
#               'however real',
#               ' particular',
#               ' only'],
#              'pattern': ['just fun',
#               ' good',
#               ' complicated',
#               ' little',
#               ' different',
#               ' careful',
#               ' appropriate',
#               'super cute',
#               ' neutral',
#               'very nice',
#               ' flattering',
#               ' eye-catching',
#               ' flattering',
#               'very retro',
#               ' fun',
#               ' visual',
#               ' airy',
#               'so beautiful'],
#              'skirt': [' flattering',
#               'quite short',
#               ' actual',
#               'though extra',
#               ' happy',
#               'already lot',
#               ' full',
#               ' afraid',
#               'however short',
#               ' top',
#               ' more',
#               'still great',
#               ' light',
#               ' flouncy',
#               'too much',
#               'very tiny',
#               ' pleated'],
#              'reviews': [' other', ' sure', ' other', ' Other'],
#              'dress': [' short',
#               'really tall',
#               'really cute',
#               'very comfortable',
#               ' sturdy',
#               'very short',
#               ' generous',
#               ' comfortable',
#               ' large',
#               ' comfortable',
#               'so fantastic',
#               'really fun',
#               'extremely comfortable',
#               'beautifully unique',
#               ' many',
#               'absolutely beautiful',
#               ' 34d',
#               'very unflattering',
#               ' grey',
#               ' cute',
#               'really staple',
#               'too big',
#               'too short',
#               ' under',
#               'extremely large',
#               'too loose',
#               'just amazing',
#               'so soft',
#               ' gorgeous',
#               ' modern',
#               'both flattering',
#               'very loose',
#               ' same',
#               ' billowy',
#               ' second',
#               ' bohemian',
#               'entirely sure',
#               ' great',
#               ' great',
#               'so soft',
#               ' curvy',
#               ' adorable',
#               ' great',
#               'too tight',
#               ' thicker',
#               'likely many',
#               'really cute',
#               ' slim',
#               ' modest',
#               ' great',
#               'completely versatile',
#               'super comfy',
#               'absolutely flattering',
#               'very cute',
#               'super comfortable',
#               ' curvier',
#               ' exact',
#               ' comfortable',
#               'too high',
#               ' usual',
#               'very flattering',
#               'really comfortable',
#               ' cheap',
#               'just bad',
#               ' neutral',
#               ' perfect',
#               ' fantastic',
#               'so excited',
#               ' fine',
#               ' right',
#               ' beautiful',
#               ' unique',
#               'actually black',
#               ' curvy',
#               ' funky',
#               ' gorgeous',
#               'too tight',
#               ' beautiful',
#               ' perfect',
#               ' adorable',
#               ' great',
#               ' great',
#               'absolutely fabulous',
#               'right small',
#               ' rare',
#               ' distinctive',
#               ' blue',
#               ' amazing',
#               'just defective',
#               ' burnt',
#               ' western',
#               ' large',
#               'super cute',
#               ' loose',
#               'also tall',
#               ' gorgeous',
#               ' fabulous',
#               ' simple',
#               'actually boring',
#               'only tall',
#               'so good',
#               ' pregnant',
#               'still shapeless',
#               'well flattering',
#               'most unflattering',
#               ' fantastic',
#               ' online',
#               ' wrinkled',
#               ' entire',
#               ' awesome',
#               ' elegant',
#               'more rigid',
#               ' great',
#               ' huge',
#               'still big',
#               'down other',
#               'so much',
#               ' curvy',
#               ' fine',
#               'really lovely',
#               'very busty',
#               ' accurate',
#               'then bigger',
#               'usually leery',
#               'absolutely adorable',
#               'too short',
#               'really nice',
#               'very happy',
#               ' exception',
#               ' adorable',
#               ' flowy',
#               ' pink',
#               ' little',
#               ' absolute',
#               'really sweet',
#               ' perfect',
#               ' cute',
#               ' worried',
#               ' obvious',
#               'extremely feminine',
#               'cleverly windy',
#               ' cute',
#               'longer back',
#               ' beautiful',
#               ' first',
#               ' little',
#               'so comfortable',
#               'absolutely hideous',
#               ' bottom',
#               ' peasant',
#               ' big',
#               'so regular',
#               ' big',
#               ' outer',
#               'just baggy',
#               ' fat',
#               ' wise',
#               'overall nice',
#               'underneath blue',
#               ' special',
#               'so cute',
#               'really sure',
#               'too short',
#               'terribly noticeable',
#               ' broad',
#               'easily classic',
#               'so cute',
#               'so ready',
#               ' big',
#               ' other',
#               'very cute',
#               'super flattering',
#               ' perfect',
#               ' small',
#               ' bigger',
#               'too much',
#               ' great',
#               'very large',
#               ' other',
#               ' adorable',
#               'so good',
#               ' gorgeous',
#               ' lightweight',
#               'really gorgeous',
#               ' excellent',
#               ' cute',
#               ' opitome',
#               ' casual',
#               ' entire',
#               ' fantastic',
#               'so comfortable',
#               ' lovely',
#               'then soft',
#               ' true',
#               ' perfect',
#               'so flattering',
#               ' new',
#               ' great',
#               ' long',
#               ' gorgeous',
#               ' amazing',
#               ' flattering',
#               ' soft',
#               'very comfortable',
#               ' small',
#               ' other',
#               'too low',
#               'so flawless',
#               'too much',
#               ' pregnant',
#               ' most',
#               ' perfect',
#               ' style',
#               ' beautiful',
#               ' soft',
#               ' amazing',
#               ' gorgeous',
#               ' wonderful',
#               'though good',
#               ' gorgeous',
#               'very roomy',
#               'overall great',
#               ' adorable',
#               ' many',
#               ' large',
#               'much lighter',
#               ' little',
#               ' great',
#               ' odd',
#               ' short',
#               'very seasonal',
#               ' first',
#               "i'm excited",
#               'really excited',
#               ' conversational',
#               'very cute',
#               ' roomy',
#               ' classy',
#               ' adorable',
#               'even better',
#               ' great',
#               'super comfortable',
#               ' adorable',
#               ' small',
#               'much better',
#               ' beautiful',
#               ' more',
#               ' beauty',
#               'so best',
#               ' small',
#               'really stunning',
#               ' gorgeous',
#               'so beautiful',
#               ' top-notch',
#               ' true',
#               ' adorable',
#               'more casual',
#               'fortunately blue',
#               'perfectly many',
#               'pretty real',
#               'even better',
#               ' first',
#               'online true',
#               ' true',
#               ' tall',
#               'even better',
#               'only extra',
#               ' little',
#               'very beautiful',
#               ' beautiful',
#               'really broad',
#               ' perfect',
#               ' other',
#               ' beautiful',
#               ' large',
#               'slightly line',
#               ' fabulous',
#               'usually large',
#               'much other',
#               ' worth',
#               'So interesting',
#               'extremely flattering',
#               ' lovely',
#               'very flattering',
#               'fairly not-so-small',
#               'really elegant',
#               'fairly straight',
#               ' perfect',
#               ' gorgeous',
#               'way better',
#               'more adorable',
#               'so adorable',
#               ' great',
#               'more stunning',
#               'very comfortable',
#               "i'm lean",
#               'first beautiful',
#               ' much',
#               'just curvy',
#               'simply gorgeous',
#               ' gorgeous',
#               'otherwise nice',
#               ' true',
#               ' perfect',
#               'perfectly flowy',
#               ' other',
#               'super flattering',
#               ' less',
#               ' perfect',
#               'overall nice',
#               'normally large',
#               'really huge',
#               'back great',
#               ' huge',
#               ' normal',
#               'so perfect',
#               ' comfortable',
#               ' awesome',
#               ' else',
#               'so perfect',
#               ' inner',
#               ' little',
#               'much prettier',
#               ' beautiful'],
#              'colors': [' cheerful',
#               ' fun',
#               'more vibrant',
#               'really easy',
#               ' gorgeous',
#               ' grey',
#               ' gorgeous',
#               ' beautiful',
#               'so many',
#               ' beautiful',
#               ' amazing',
#               ' better',
#               'quite happy',
#               'so beautiful',
#               ' soft',
#               'online accurate',
#               ' beautiful',
#               ' fun',
#               ' brighter',
#               ' perfect',
#               ' gorgeous',
#               ' rich',
#               ' great',
#               'pretty pink',
#               'so many',
#               ' vibrant',
#               ' nice',
#               'so fun',
#               ' vibrant',
#               ' vibrant',
#               'aside vibrant',
#               'Just beautiful',
#               ' vibrant',
#               'very fall',
#               ' great',
#               ' warm',
#               ' great',
#               ' stunning',
#               ' happy',
#               ' great',
#               ' neutral',
#               ' nice',
#               ' beautiful',
#               'very soft',
#               'too vibrant'],
#              'top': [' fine',
#               ' cotton',
#               ' fine',
#               ' full',
#               ' little',
#               ' flattering',
#               'too large',
#               'though tight',
#               'firstly strange',
#               ' great',
#               'still tad'],
#              'issue': [' only', ' sure', ' fabric', ' only'],
#              'length': [' horizontal',
#               ' perfect',
#               'most likely',
#               ' regular',
#               ' good',
#               ' longer',
#               ' little',
#               'very versatile',
#               ' good',
#               ' few',
#               ' Perfect',
#               ' great',
#               ' right',
#               'also great',
#               'so fine',
#               'too short',
#               'very nice',
#               ' perfect',
#               ' flowey',
#               'longer most',
#               ' accurate',
#               ' perfect',
#               'also perfect',
#               ' shorter',
#               'slightly knee',
#               'well knee',
#               ' regular',
#               'so awkward',
#               ' perfect',
#               ' perfect',
#               'pretty tall',
#               ' good',
#               ' huge',
#               'long enough',
#               'so great',
#               'that much',
#               ' perfect',
#               'just knee',
#               'so regular',
#               ' delightful',
#               ' fine',
#               'somewhat awkward',
#               ' regular',
#               'also perfect',
#               'so shorter',
#               ' slim'],
#              'hubby': ['more else'],
#              'style': ['super flattering',
#               ' bohemian',
#               ' overall',
#               ' nice',
#               'so straight',
#               'so nice',
#               'very flattering',
#               ' fun',
#               'all perfect',
#               ' cute'],
#              'lines': [' horizontal', ' swirly'],
#              'price': [' huge', ' amazing', ' high', ' right'],
#              'hem': ['absolutely regular',
#               ' bottom',
#               ' asymmetrical',
#               ' petite',
#               ' bohemian'],
#              'embroidery': [' lovely',
#               ' little',
#               ' beautiful',
#               ' white',
#               'perfectly nice',
#               ' stunning',
#               ' bright',
#               'really high',
#               ' great',
#               'even big',
#               ' exquisite',
#               ' loose',
#               ' beautiful'],
#              'p': ['just fine'],
#              'way': ['too snug',
#               'too much',
#               ' great',
#               'usually loose',
#               ' wrong',
#               'much tighter'],
#              'things': ['too many', ' key'],
#              'fits': [' perfect'],
#              'thing': ['really awesome',
#               'most important',
#               'then tent-like',
#               ' crazy',
#               ' interesting',
#               ' only',
#               ' only',
#               ' only',
#               'so cold'],
#              'model': [" '", ' tall'],
#              'size': [' small',
#               ' typical',
#               ' regular',
#               ' small',
#               'only available',
#               ' true',
#               'only available',
#               ' best',
#               ' usual',
#               ' full',
#               'only smallest',
#               'too big',
#               ' perfect',
#               'usually great',
#               ' perfect',
#               ' smaller',
#               ' bright',
#               'perhaps regualr',
#               'not sure',
#               ' regular',
#               ' great',
#               ' available',
#               ' petite',
#               ' regular',
#               ' larger',
#               ' boxy'],
#              'cut': [' tight',
#               'very flattering',
#               'so flattering',
#               'just good',
#               ' larger',
#               ' more',
#               ' flattering',
#               ' loose',
#               ' flattering',
#               ' loose',
#               'really true',
#               'actualyl flattering',
#               'very attractive',
#               ' awesome',
#               ' great',
#               'way armpit',
#               'nicely true',
#               'too hippy',
#               'perfectly big',
#               'still flattering'],
#              'placket': [' soft'],
#              'pleats': [' different', ' petite', 'better odd'],
#              'frabic': ['recently new'],
#              'slip': [' full',
#               ' straight',
#               'so fine',
#               'also separate',
#               ' soft',
#               'underneath big',
#               'slightly tight',
#               ' snug',
#               'perfectly outer',
#               ' large',
#               'underneath tight',
#               'still fine',
#               ' nice',
#               ' tts',
#               'underneath great',
#               'also tiny',
#               ' least',
#               'anyway pretty',
#               ' fine',
#               'underneath form',
#               'very small',
#               'underneath substantial',
#               'super small',
#               ' large',
#               ' smaller',
#               'too inner',
#               ' adjustable',
#               'usually little'],
#              'waist': [' petite',
#               'much lower',
#               'definitely elastic',
#               'quite small',
#               ' gorgeous',
#               ' comfortable',
#               'only minor',
#               ' long',
#               ' little',
#               'on normal',
#               ' pretty',
#               'somewhat broad',
#               ' higher',
#               ' elastic'],
#              'm': ['too big', ' perfect', ' great'],
#              'color': ['even black',
#               ' favorites',
#               'more earthy',
#               ' grey',
#               ' difficult',
#               ' dark',
#               'pretty deep',
#               'very peppery',
#               ' true',
#               'pretty person',
#               ' gorgeous',
#               ' great',
#               'almost neon',
#               'unfortunatly aweful',
#               ' neutral',
#               'actually deep',
#               ' beautiful',
#               ' blue',
#               'beautifully blue',
#               ' rich',
#               ' gray',
#               ' beautiful',
#               ' blue',
#               ' deep',
#               ' beautiful',
#               ' prett',
#               'more vibrant',
#               ' little',
#               ' sure',
#               ' great',
#               ' orange',
#               ' red',
#               ' blue',
#               'so blue',
#               ' blue',
#               'also blue',
#               ' blue',
#               ' blue',
#               ' darker'],
#              'reviewer': [' last',
#               ' same',
#               ' same',
#               ' different',
#               'very excited',
#               ' big',
#               ' huge',
#               ' essential',
#               ' previous',
#               'first perfect',
#               ' tiny'],
#              'dresses': ['very most',
#               ' happy',
#               'sometimes elastic',
#               ' many',
#               'sometimes a-line',
#               'just retro',
#               ' more',
#               'so flattering',
#               'so least',
#               ' tall',
#               ' uniform',
#               'why regular',
#               ' amazing',
#               ' favorite'],
#              'sleeves': [' sheer',
#               'seriously sheer',
#               ' puffy',
#               'quite large',
#               ' puffy',
#               'well large',
#               'so small',
#               'really big',
#               ' perfect',
#               'nicely annoying',
#               ' nice',
#               ' little',
#               'really cute',
#               ' tight',
#               'too keen',
#               'slightly full',
#               ' voluminous',
#               ' large',
#               ' long',
#               'usually right',
#               ' nice',
#               ' easy',
#               ' low'],
#              'grey': ['more vibrant', 'very blueish'],
#              'picture': [' real', 'mostly blac', ' unique'],
#              'red': [' perfect', ' deeper', 'both gorgeous'],
#              'fit': [' more',
#               'too large',
#               ' flowy',
#               'super comfy',
#               ' great',
#               'so strange',
#               'just bad',
#               ' good',
#               'more brown',
#               'beautifully fantastic',
#               ' great',
#               ' overall',
#               ' perfect',
#               ' tricky',
#               'just better',
#               ' comfortable',
#               ' perfect',
#               'usually only',
#               'extremely loose',
#               ' comfortable',
#               ' other',
#               'really flattering',
#               ' beautiful',
#               ' wonderful',
#               'Very pretty',
#               ' great',
#               ' perfect',
#               'still opaque',
#               'so excited',
#               'incredibly flattering',
#               ' flattering',
#               'very unflattering',
#               'off big',
#               ' boxy',
#               ' cool',
#               'pretty good',
#               ' small',
#               ' fine',
#               ' beautiful',
#               ' flattering',
#               ' perfect',
#               ' perfect',
#               'otherwise fine',
#               ' good',
#               ' fantastic',
#               ' fabulous',
#               ' true'],
#              'l': ['too big'],
#              'reviewers': [' other',
#               ' many',
#               ' other',
#               ' other',
#               ' other',
#               ' other',
#               ' other',
#               ' other',
#               ' other',
#               ' other',
#               ' other',
#               'however other',
#               ' other'],
#              'buttons': ['very tight', ' new', ' sturdy', ' nice', ' warm'],
#              'inventory': ['also online'],
#              'shape': [' extra',
#               ' nice',
#               ' true',
#               'otherwise tented',
#               ' basic',
#               ' a-line',
#               'really good',
#               ' good'],
#              'xs': ['too wide',
#               ' best',
#               'usually better',
#               ' regular',
#               ' perfect',
#               'too large',
#               'so kind',
#               ' large'],
#              'pockets': [' awesome',
#               ' nice',
#               ' unlined',
#               'as many',
#               ' weird',
#               ' comfortable'],
#              'band': ['somewhat big', ' big', 'also elastic'],
#              'seam': [' little', ' lower', ' top', ' bottom'],
#              '#39': [' simple'],
#              'drawback': [' only', ' only'],
#              'colour': [' gorgeous'],
#              'school': [' secular'],
#              'holes': [' tight',
#               'then top',
#               'also great',
#               'very interesting',
#               'too upper',
#               ' large',
#               'so uncomfortable',
#               ' little'],
#              'plaid': ['underneath nice'],
#              'lacing': ['completely useless'],
#              'bottom': ['also front', 'too ample', 'very thin', 'all dirty'],
#              'ps': [' perfect'],
#              'print': [' tall',
#               'recently versatile',
#               'so thrilled',
#               'super cute',
#               ' fun',
#               'much better',
#               ' pretty',
#               ' cute',
#               ' different',
#               'very white',
#               ' usual',
#               'hardly adorable',
#               ' old',
#               ' gorgeous',
#               ' lovely',
#               ' turquoise',
#               'alas adorable',
#               'so elegant',
#               ' face'],
#              'tassels': ['so black'],
#              'ladies': [' armed', ' large-chested'],
#              'part': [' only',
#               ' hardest',
#               'very nice',
#               ' sheer',
#               ' best',
#               ' outer',
#               ' good',
#               ' bottom',
#               ' see-though',
#               ' top',
#               ' top',
#               ' weird',
#               ' lighter',
#               ' softer',
#               'occasionally top',
#               'so top',
#               ' top',
#               'down upper',
#               'so top'],
#              'pictures': ['then few',
#               'accurately large',
#               ' nice',
#               'then other',
#               'really beautiful'],
#              'lining': [' tts',
#               ' outer',
#               'super soft',
#               ' heavier',
#               'really soft',
#               'wide true',
#               ' opaque',
#               ' awkward',
#               'then tight',
#               ' substantial',
#               'super flattering',
#               ' hot',
#               'very sheer',
#               'much smaller'],
#              'complaint': [' only',
#               ' only',
#               ' tiny',
#               ' only',
#               ' only',
#               ' only',
#               ' little',
#               ' only',
#               'also only',
#               ' only'],
#              'stripes': [' fun', 'really horizontal', ' white'],
#              'medium': ['generally perfect',
#               ' perfect',
#               ' correct',
#               ' fine',
#               ' muscular',
#               ' sure',
#               'normally large'],
#              "i'm": ['probably shortest',
#               'often relaxed',
#               ' long',
#               ' petite',
#               'always petite'],
#              'people': [' many', ' many'],
#              'arms': [' ok',
#               ' smaller',
#               'perfectly personal',
#               'pretty small',
#               'definitely smaller'],
#              'stylist': [' usual'],
#              'turtleneck': ['too tight', 'as flattering', ' tight'],
#              'friend': ['also favorite', ' same'],
#              'negative': [' only'],
#              'description': [' best'],
#              'sizes': ['online difficult', ' bottom', ' same', ' petite'],
#              'design': [' black',
#               'super flattering',
#               'also perfect',
#               'so worth',
#               ' adorable',
#               'pretty nice',
#               ' adorable',
#               ' big',
#               'overall beautiful',
#               ' short',
#               ' classy',
#               ' perfect',
#               'very skinny',
#               ' cute',
#               'yet beautiful'],
#              'quality': [' great',
#               'very nice',
#               ' great',
#               'otherwise lovely',
#               ' great',
#               ' better',
#               'really nice',
#               ' excellent',
#               ' point',
#               ' good',
#               ' nice',
#               'very comfortable',
#               'super comfortable',
#               ' edgy'],
#              'retailer': ['again beautiful', ' classic', 'too late'],
#              'shipping': [' quick', 'too small'],
#              'sweater': [' grey'],
#              'assets': ['particularly clingy'],
#              'swing': [' asymmetrical'],
#              'hemline': ['more awkward'],
#              'stretch': [' light', 'so someth'],
#              'navy': ['pretty dark'],
#              'layer': [' top', ' delicate', ' outer'],
#              'sheath': [' inner'],
#              'overlay': [' lattice', ' loose', 'very different', ' lovely'],
#              'v-neckline': [' deep'],
#              'detail': [' nice',
#               'Really cute',
#               'really cute',
#               ' nice',
#               ' extra',
#               'very flattering',
#               ' beautiful',
#               ' bottom',
#               ' nice',
#               ' exquisite'],
#              'fabrics': [' beautiful', ' elegant'],
#              'zipper': [' tricky',
#               ' tricky',
#               ' stuck',
#               ' side',
#               'literally horrible',
#               ' 2nd',
#               ' cheap',
#               'super cheap',
#               ' classy'],
#              'half': [' bottom', ' bottom', ' bottom', ' fine'],
#              'gaps': ['too unattractive'],
#              'photos': [' gorgeous',
#               'not vibrant',
#               'as gauzy',
#               'even hot',
#               ' beautiful',
#               'definitely more'],
#              'details': ['too much',
#               ' high',
#               ' breathtaking',
#               'well abundant',
#               ' exquisite',
#               ' little',
#               ' lovely'],
#              'wasit': [' comfortable'],
#              'waistband': ['right elastic', 'more flattering'],
#              'shirt': ['too poofy'],
#              'expectations': [' neutral'],
#              'v-neck': [' perfect'],
#              'linen': [' big'],
#              'guy': ['already great'],
#              'mango': [' disappointed'],
#              'shade': ['quite muddy', ' lighter'],
#              'area': ['however tight', ' hips', 'however striped'],
#              'lot': ['very wide', 'very slight', ' loose'],
#              'images': ['so fine'],
#              'heads': [' dark'],
#              'others': [' large', ' tall'],
#              'escalante': [' marvelous'],
#              'fitting': [' loose'],
#              'Dress': ['very cute', ' true'],
#              'tailor': [' good'],
#              'room': ['however unforgiving', 'much extra', ' more', ' small'],
#              'chest': [' aghast'],
#              'body': [' tight', ' more'],
#              'lack': [' only'],
#              'patters': ['more stunning'],
#              'armholes': [' big',
#               'too tight',
#               'so overwhelming',
#               'totally bizarre',
#               'so long',
#               ' little'],
#              'associate': ['super cute'],
#              'mixture': ['very unique'],
#              'smalls': ['usually extra'],
#              'sa': ['even smaller'],
#              'photo': [' nice', ' negative', ' blue', ' other', ' least'],
#              'needles': ['pretty little'],
#              'wool': ['pretty high'],
#              'mixing': [' great'],
#              'store': ['so many',
#               ' local',
#               'so lbs',
#               'online local',
#               ' white'],
#              'weight': [' synthetic', ' graceful', 'there little'],
#              'gals': [' other'],
#              'pink': [' perfect',
#               'just beautiful',
#               ' gorgeous',
#               ' ridiculous',
#               ' only',
#               'really bright',
#               ' Pale'],
#              'feel': [' amazing', ' young', ' thick'],
#              'movement': ['very fun'],
#              'piping': [' green'],
#              'iron': [' dry'],
#              'gauze': ['sometimes cheap'],
#              'trim': ['more tone', ' black'],
#              'wish': [' only', "i'm only"],
#              'comments': [' stiff'],
#              'difference': [' biggest', ' sure'],
#              'portion': ['quite flowy', ' great', ' top', ' little'],
#              'concern': [' other'],
#              'spring': ['immediately opposite'],
#              'liner': [' unsung', 'more noticeable'],
#              'rompers': ['soo cute'],
#              'flowy': [' great'],
#              'romper': [' cute', ' fabulous'],
#              'garment': [' loose'],
#              'shoulders': [' roomy'],
#              'snap': [' top'],
#              'rest': ['all good', ' fine', ' tight', 'really odd'],
#              'struggle': [' hard'],
#              'grommets': [' little'],
#              'looseness': [' good'],
#              'waistline': [' high-waisted'],
#              'studs': [' edgier'],
#              'off': [' comfortable'],
#              'layers': [' great'],
#              'patterns': [' busy', ' different', 'particularly unique'],
#              'dilemma': [' fold'],
#              'women': [' rural', 'so taller', ' smaller'],
#              'stitching': ['also orange', 'even fuzzy'],
#              'pieces': [' transparent'],
#              'look': ['so bad', ' overall'],
#              'empire': ['so particular'],
#              't': ['perfectly 5&'],
#              'over-dress': [' beautiful'],
#              'under-slip': ['very tight'],
#              'sparkle': [' appropriate'],
#              'slits': [' bigger', ' higher'],
#              'neckline': [' wide',
#               ' sheer',
#               ' little',
#               'pretty small',
#               'too full'],
#              'woman': [' colder', ' same'],
#              'arm': ['somewhat tight'],
#              'back': ['somewhat short',
#               ' adorable',
#               ' low',
#               ' nice',
#               ' low',
#               ' flat',
#               'very low',
#               'just flattering'],
#              'fiber': [' natural'],
#              'bodice': ['more true',
#               ' perfect',
#               'more peach',
#               ' new',
#               ' bigger'],
#              'front': ['much shorter', 'too short', 'too tiny', ' flattering'],
#              'center': [' sheer', ' nice'],
#              'button': ['very low', 'too tight'],
#              'sleeve': ['not mid'],
#              'strip': ['fyi first'],
#              'lace': [' soft', 'overall great'],
#              'snag': [' other', ' terrible'],
#              'potential': ['too high'],
#              'pulling': [' bigger'],
#              '00p': ['just snugger'],
#              'maeve': [' large', ' great'],
#              'converse': ['also white'],
#              'order': [' online'],
#              'blue': [' great', 'so beautiful'],
#              'seasons': [' Nice'],
#              'stature': ['online pettie'],
#              'shell': [' outer'],
#              'check': ['so second'],
#              'sizing': [' loose',
#               ' straightforward',
#               ' perfect',
#               ' little',
#               'definitely petite',
#               ' impossible',
#               ' generous'],
#              'striping': ['more red'],
#              "dind't": [' flattering'],
#              'plenty': [' chested'],
#              'tie': ['very cute',
#               ' little',
#               ' fun',
#               'really difficult',
#               ' afraid',
#               ' interesting'],
#              'amount': [' right', ' worth'],
#              'cons': [' only'],
#              'bra': [' great', 'not enough'],
#              'xxs': ['usually looser'],
#              'number': [' lovely', 'also loose'],
#              'strops': [' elastic'],
#              'ties': [' different'],
#              'weather': ['often warm', ' warmer', 'now cooler'],
#              'thin-ish': ['super comfortable'],
#              'balance': [' nice'],
#              'tuck': ['just odd'],
#              'stores': [' more'],
#              'sale': [' full'],
#              'winner': ['online clear'],
#              'prints': ['all great'],
#              'finishing': [' moderate'],
#              'fact': [' washable'],
#              'sides': ['almost white'],
#              'xl': [' looser', 'even flattering'],
#              'xxsp': [' regular', ' tall'],
#              'tangerine': ['online red'],
#              'scoop': ['especially soft'],
#              'belt': ['very thin'],
#              's': ['usually perfect', 'really vibrant'],
#              'mother': [' blue'],
#              'boobs': ['also ok', 'otherwise 30dd'],
#              'boyfriend': [' pregnan'],
#              'tag': [' dry'],
#              'person': [' slim'],
#              'pleat': [' first'],
#              'tunic': [' lovely'],
#              'velvet': [' point',
#               'however taller',
#               'back loving',
#               ' such',
#               ' sublime',
#               'finally gorgeous'],
#              'piece': ['so great'],
#              'hole': ['just random'],
#              'shift': [' baggy'],
#              'surprise': ['online pleasant'],
#              'loosness': [' easy'],
#              'petites': ["i'm short", ' regular', 'unfortunately available'],
#              'epite': [' least'],
#              'cotton': [' nice', ' soft', 'also nice'],
#              'bust': ['too large',
#               'much better',
#               ' way',
#               'not other',
#               ' wide'],
#              'strap': ['just right'],
#              'site': [' more'],
#              'canvas': [' thicker'],
#              'combination': ['however large-'],
#              '1960s': [' early'],
#              'Maeve': [' many'],
#              'level': ['just unmatched'],
#              'boning': [' front'],
#              'hips': ['very bohemian'],
#              'plunge': [' aware', 'too deep'],
#              'elngth': ['almsot sweet'],
#              'pop': [' gray'],
#              'reservation': [' only'],
#              'orange': ['however sweet'],
#              'ruffle': [' interesting'],
#              'net': ['so fabled'],
#              'section': ['slightly big'],
#              'crystals': ['online high'],
#              'Pictures': [' beautiful'],
#              'ends': [' frayed'],
#              'replacement': [' better'],
#              'zippers': [' faulty'],
#              'line': [' high', ' little'],
#              'flaw': ['however biggest', ' only'],
#              'issues': [' several'],
#              'bow': ['really cute'],
#              'product': [' terrible'],
#              '2p': [' fine'],
#              '0p': ['too small'],
#              '4p': [' perfect'],
#              'areas': [' floral'],
#              'flare': ["i'm lower"],
#              'combo': [' unique'],
#              'shot': [' top'],
#              'edging': [' unfinished'],
#              'angle': ['even bigger'],
#              'pleating': ['very cute'],
#              'fringe': ['so special'],
#              'side': [' only'],
#              'sp': ['unfortunately enormous'],
#              'boots': [' nice'],
#              'set': [' high'],
#              'pm': ['too big'],
#              'tape': ['usually double'],
#              "'": [' petite'],
#              'supper': [' flattering'],
#              'critique': [' only'],
#              'bunching': ['less clean'],
#              'construction': [' little'],
#              'transition': [' wrong', ' extra'],
#              'slit': ['just right'],
#              'fold': [' extra'],
#              'uses': ['so many'],
#              'brand': ['always great'],
#              'motif': [' one'],
#              'inside': [' white'],
#              'maxis': [' better'],
#              'ruching': ['just itchy'],
#              'catch': [' right'],
#              'small': ['too big'],
#              'clerk': [' large'],
#              'day': ['already several'],
#              'gathering': [' floral'],
#              'husband': [' many'],
#              'plan': ['yet sure'],
#              'silhouette': [' odd'],
#              'collar': [' unique', ' french', 'slightly past'],
#              'cat': [' yucky'],
#              'linings': [' many']})

# %%
#saving the final output in csv
df.to_csv('Womens Clothing E-Commerce Reviews Aspect-Opinion.csv')
